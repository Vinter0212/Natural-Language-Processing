# %%
from collections import defaultdict
import numpy as np
import math

# %%
import nltk
nltk.download('universal_tagset')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\vinay\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\vinay\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
# To perform Laplace smoothing
def laplace_smoothing(num,den):
    return (num+0.001)/(den+0.001)

# %%
# Calculates initial state distribution
def initial_state_dis(corpus):
    count_POS =defaultdict(int)
    total_count=len(corpus)
    for i in corpus:
        count_POS[i[0][1]]+=1
    for i in count_POS:
        count_POS[i]= laplace_smoothing(count_POS[i],total_count)
    return count_POS

# %%
# gets a list of POS occuring in the training dat
def get_all_POS(corpus):
    all_POS=[]
    for i in corpus:
        for j in i:
            all_POS.append(j[1])
    all_POS=list(set(all_POS))
    return all_POS

# %%
# Maps every POS to a number so as to be used in Transition and Observation matrices
def map_index(all_POS):
    map_index ={}
    for idx,i in enumerate(all_POS):
        map_index[i]=idx
    return map_index

# %%
# Creates the Transition Matrix
def transition_matrix(corpus,map_pos_idx):
    num_pos = len(map_pos_idx)
    transition_mat = [[0 for j in range(num_pos)] for i in range(num_pos)]
    for i in corpus:
        for j in range(len(i)-1):
            transition_mat[map_pos_idx[i[j][1]]][map_pos_idx[i[j+1][1]]]+=1
    for i in range(num_pos):
        current_len=sum(transition_mat[i])
        for j in range(num_pos):
            transition_mat[i][j] = laplace_smoothing(transition_mat[i][j],current_len)
    return np.array(transition_mat)

# %%
# Creates the vocabulary of words taking OOV into account
def create_Vocab(corpus):
    vocab_count =defaultdict(int)
    for i in corpus:
        for j in i:
            vocab_count[j[0].lower()]+=1
    new_vocab_count=defaultdict(int)
    for i in vocab_count:
        if(vocab_count[i]>=5):
            new_vocab_count[i]=vocab_count[i]
    return ['OOV']+list(new_vocab_count.keys())

# %%
# Creates the observation matrix
def observation_matrix(corpus,map_pos_idx,vocab_index):
    rows = len(map_pos_idx)
    cols =len(vocab_index)
    observation_mat = [[0 for j in range(cols)] for i in range(rows)]
    for i in corpus:
        for j in i:
            if j[0].lower() in vocab_index:
                observation_mat[map_pos_idx[j[1]]][vocab_index[j[0].lower()]]+=1
            else:
                observation_mat[map_pos_idx[j[1]]][0]+=1
    for i in range(rows):
        current_len=sum(observation_mat[i])
        for j in range(cols):
            observation_mat[i][j] = laplace_smoothing(observation_mat[i][j],current_len)
    return np.array(observation_mat)

# %%
# Maps the initial state distriution to an index
def createInitialMap(initial_state,all_POS):
    return [initial_state[i] for i in all_POS]

# %%
# Convert observation to appropriate index in the vocabulary
def createobs(test_data,vocab_index):
    row=len(test_data)
    obs =[]
    for i in test_data:
        cur_test=[]
        for j in i:
            if j[0].lower() in vocab_index:
                cur_test.append(vocab_index[j[0].lower()])
            else:
                cur_test.append(0)
        obs.append(cur_test)
    return obs

# %% [markdown]
# **Corpus**

# %%
corpus=nltk.corpus.brown.tagged_sents(tagset='universal')[:10000]
corpus
# Out:
# [[('The', 'DET'), ('Fulton', 'NOUN'), ('County', 'NOUN'), ('Grand', 'ADJ'), ('Jury', 'NOUN'), ('said', 'VERB'), ('Friday', 'NOUN'), ('an', 'DET'), ('investigation', 'NOUN'), ('of', 'ADP'), ("Atlanta's", 'NOUN'), ('recent', 'ADJ'), ('primary', 'NOUN'), ('election', 'NOUN'), ('produced', 'VERB'), ('``', '.'), ('no', 'DET'), ('evidence', 'NOUN'), ("''", '.'), ('that', 'ADP'), ('any', 'DET'), ('irregularities', 'NOUN'), ('took', 'VERB'), ('place', 'NOUN'), ('.', '.')], [('The', 'DET'), ('jury', 'NOUN'), ('further', 'ADV'), ('said', 'VERB'), ('in', 'ADP'), ('term-end', 'NOUN'), ('presentments', 'NOUN'), ('that', 'ADP'), ('the', 'DET'), ('City', 'NOUN'), ('Executive', 'ADJ'), ('Committee', 'NOUN'), (',', '.'), ('which', 'DET'), ('had', 'VERB'), ('over-all', 'ADJ'), ('charge', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('election', 'NOUN'), (',', '.'), ('``', '.'), ('deserves', 'VERB'), ('the', 'DET'), ('praise', 'NOUN'), ('and', 'CONJ'), ('thanks', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('City', 'NOUN'), ('of', 'ADP'), ('Atlanta', 'NOUN'), ("''", '.'), ('for', 'ADP'), ('the', 'DET'), ('manner', 'NOUN'), ('in', 'ADP'), ('which', 'DET'), ('the', 'DET'), ('election', 'NOUN'), ('was', 'VERB'), ('conducted', 'VERB'), ('.', '.')], ...]

# %% [markdown]
# **Initial state distribution**

# %%
initial_state= initial_state_dis(corpus)
initial_state
# Out:
# defaultdict(int,
#             {'DET': 0.24030007596999242,
#              '.': 0.06500009349999064,
#              'PRON': 0.11340008865999113,
#              'NOUN': 0.19650008034999195,
#              'ADV': 0.07750009224999077,
#              'ADP': 0.1207000879299912,
#              'VERB': 0.04100009589999041,
#              'NUM': 0.017300098269990172,
#              'CONJ': 0.054900094509990546,
#              'ADJ': 0.04220009577999042,
#              'PRT': 0.030700096929990303,
#              'X': 0.000500099949990005})

# %%
all_POS=get_all_POS(corpus)
map_pos_idx=map_index(all_POS)

# %% [markdown]
# **Total Part of speech**

# %%
all_POS
# Out:
# ['DET',
#  'ADJ',
#  '.',
#  'NOUN',
#  'PRT',
#  'NUM',
#  'X',
#  'CONJ',
#  'VERB',
#  'PRON',
#  'ADV',
#  'ADP']

# %%
map_pos_idx
# Out:
# {'DET': 0,
#  'ADJ': 1,
#  '.': 2,
#  'NOUN': 3,
#  'PRT': 4,
#  'NUM': 5,
#  'X': 6,
#  'CONJ': 7,
#  'VERB': 8,
#  'PRON': 9,
#  'ADV': 10,
#  'ADP': 11}

# %% [markdown]
# **Transition matrix**

# %%
A=transition_matrix(corpus,map_pos_idx)
A
# Out:
# array([[6.43078157e-03, 2.50370284e-01, 1.29004984e-02, 6.15636464e-01,
#         1.55900688e-03, 1.33681887e-02, 1.52003268e-03, 5.06703542e-04,
#         6.14623485e-02, 8.37949145e-03, 1.88635506e-02, 9.00307861e-03],
#        [6.03480609e-03, 5.92502859e-02, 8.94240116e-02, 6.74855247e-01,
#         1.85309955e-02, 1.28010355e-02, 6.09631173e-04, 3.32825947e-02,
#         1.54831444e-02, 2.37738480e-03, 7.61968865e-03, 7.97318452e-02],
#        [1.20139515e-01, 5.28306906e-02, 1.41649974e-01, 1.78997803e-01,
#         2.01513403e-02, 2.13332336e-02, 1.95018308e-03, 9.38423890e-02,
#         1.30776555e-01, 6.38813932e-02, 6.30540679e-02, 1.11393505e-01],
#        [1.41032272e-02, 1.56665151e-02, 2.64632724e-01, 2.12203745e-01,
#         1.74651367e-02, 9.69912574e-03, 4.70684141e-04, 5.25130433e-02,
#         1.44024220e-01, 1.77340895e-02, 2.28105728e-02, 2.28677102e-01],
#        [8.46823757e-02, 1.89500555e-02, 4.65852652e-02, 4.14530120e-02,
#         8.68554902e-03, 7.10639418e-03, 1.97591749e-04, 7.89597160e-03,
#         6.61666075e-01, 3.15850707e-03, 3.05963224e-02, 8.90250515e-02],
#        [1.03451120e-02, 6.83910723e-02, 2.54023203e-01, 3.82184086e-01,
#         6.60948086e-03, 2.32761427e-02, 2.87643596e-04, 3.36209674e-02,
#         4.39657920e-02, 5.17269966e-03, 3.18968299e-02, 1.40230132e-01],
#        [3.94092937e-03, 3.94092937e-03, 2.63782426e-01, 1.06302731e-01,
#         3.94092937e-03, 3.94092937e-03, 4.60632045e-01, 1.96888989e-02,
#         5.11848379e-02, 3.93699237e-06, 1.18149141e-02, 7.08697997e-02],
#        [1.57147302e-01, 1.17558308e-01, 2.29678116e-02, 2.89815762e-01,
#         2.35722237e-02, 1.94924419e-02, 3.02357162e-04, 4.53460191e-04,
#         1.60320465e-01, 5.25840054e-02, 8.80932173e-02, 6.76943083e-02],
#        [1.76832308e-01, 5.83673508e-02, 7.15919209e-02, 1.11172936e-01,
#         6.34347094e-02, 1.25757319e-02, 1.85422068e-04, 1.19886599e-02,
#         1.93610209e-01, 3.89939736e-02, 9.57236715e-02, 1.65523447e-01],
#        [1.40154582e-02, 9.10287399e-03, 8.17802223e-02, 8.95838622e-03,
#         2.23957488e-02, 7.22583337e-04, 1.44487770e-07, 1.17036539e-02,
#         7.33275577e-01, 9.24736176e-03, 5.92401301e-02, 4.95594496e-02],
#        [8.06657748e-02, 1.50413488e-01, 1.39919531e-01, 4.01739410e-02,
#         2.93619854e-02, 1.54760425e-02, 2.12105129e-04, 1.36740499e-02,
#         2.59169042e-01, 3.62519571e-02, 9.63537104e-02, 1.38329538e-01],
#        [4.43147528e-01, 8.45791632e-02, 1.13778993e-02, 2.87281858e-01,
#         1.21879736e-02, 3.90308919e-02, 3.68252435e-04, 1.28879147e-03,
#         3.85153900e-02, 4.96723231e-02, 1.36240145e-02, 1.89263194e-02]])

# %% [markdown]
# **Vocabulary**

# %%
vocab=create_Vocab(corpus)
vocab
# Out:
# ['OOV',
#  'the',
#  'fulton',
#  'county',
#  'grand',
#  'jury',
#  'said',
#  'friday',
#  'an',
#  'investigation',
#  'of',
#  'recent',
#  'primary',
#  'election',
#  'produced',
#  '``',
#  'no',
#  'evidence',
#  "''",
#  'that',
#  'any',
#  'took',
#  'place',
#  '.',
#  'further',
#  'in',
#  'city',
#  'executive',
#  'committee',
#  ',',
#  'which',
#  'had',
#  'over-all',
#  'charge',
#  'deserves',
#  'praise',
#  'and',
#  'thanks',
#  'atlanta',
#  'for',
#  'manner',
#  'was',
#  'conducted',
#  'term',
#  'been',
#  'charged',
#  'by',
#  'superior',
#  'court',
#  'judge',
#  'to',
#  'reports',
#  'possible',
#  'won',
#  'allen',
#  'jr.',
#  'only',
#  'a',
#  'relative',
#  'such',
#  'received',
#  'considering',
#  'widespread',
#  'interest',
#  'number',
#  'voters',
#  'size',
#  'this',
#  'it',
#  'did',
#  'find',
#  'many',
#  "georgia's",
#  'laws',
#  'are',
#  'or',
#  'inadequate',
#  'often',
#  'recommended',
#  'legislators',
#  'act',
#  'have',
#  'these',
#  'studied',
#  'revised',
#  'end',
#  'improving',
#  'them',
#  'commented',
#  'on',
#  'other',
#  'among',
#  'purchasing',
#  'departments',
#  'well',
#  'follow',
#  'generally',
#  'accepted',
#  'practices',
#  'best',
#  'both',
#  'governments',
#  'merger',
#  'proposed',
#  'however',
#  'believes',
#  'two',
#  'offices',
#  'should',
#  'be',
#  'combined',
#  'achieve',
#  'greater',
#  'reduce',
#  'cost',
#  'administration',
#  'department',
#  'is',
#  'lacking',
#  'experienced',
#  'clerical',
#  'personnel',
#  'as',
#  'result',
#  'policies',
#  'urged',
#  'take',
#  'steps',
#  'problem',
#  'automobile',
#  'title',
#  'law',
#  'also',
#  'next',
#  'legislature',
#  'provide',
#  'enabling',
#  'funds',
#  'effective',
#  'date',
#  'so',
#  'orderly',
#  'may',
#  'at',
#  'state',
#  'welfare',
#  'federal',
#  'granted',
#  'child',
#  'services',
#  'homes',
#  'one',
#  'major',
#  'items',
#  'general',
#  'assistance',
#  'program',
#  'but',
#  'has',
#  'seen',
#  'fit',
#  'through',
#  'all',
#  'counties',
#  'with',
#  'exception',
#  'receives',
#  'none',
#  'money',
#  'they',
#  'realize',
#  'distribution',
#  'might',
#  'our',
#  'less',
#  'nevertheless',
#  'we',
#  'feel',
#  'future',
#  'receive',
#  'some',
#  'portion',
#  'available',
#  'failure',
#  'do',
#  'will',
#  'continue',
#  'burden',
#  'taxpayers',
#  'under',
#  'fire',
#  'its',
#  'appointment',
#  'fees',
#  'compensation',
#  'protected',
#  'found',
#  'into',
#  'operating',
#  'procedures',
#  'recommendations',
#  'previous',
#  'bar',
#  'association',
#  'citizens',
#  'actions',
#  'serve',
#  'protect',
#  'fact',
#  'effect',
#  'from',
#  'costs',
#  'appointed',
#  'elected',
#  'servants',
#  'regarding',
#  'new',
#  'airport',
#  'when',
#  'management',
#  'takes',
#  'jan.',
#  '1',
#  'eliminate',
#  'political',
#  'not',
#  'elaborate',
#  'added',
#  'there',
#  'purpose',
#  'keeping',
#  'prices',
#  'reasonable',
#  'ask',
#  'jail',
#  'deputies',
#  'matters',
#  ':',
#  '(',
#  ')',
#  'four',
#  'additional',
#  'employed',
#  'doctor',
#  'medical',
#  'night',
#  'weekend',
#  'duty',
#  '2',
#  'work',
#  'officials',
#  'pass',
#  'legislation',
#  'permit',
#  'establishment',
#  'fair',
#  'pension',
#  'plan',
#  'employes',
#  'praised',
#  'operation',
#  'police',
#  'tax',
#  'office',
#  'prison',
#  'grady',
#  'hospital',
#  'health',
#  'mayor',
#  'william',
#  'b.',
#  'hartsfield',
#  'filed',
#  'suit',
#  'divorce',
#  'his',
#  'wife',
#  'pearl',
#  'williams',
#  'petition',
#  'mental',
#  'couple',
#  'married',
#  'aug.',
#  'son',
#  'berry',
#  'daughter',
#  'mrs.',
#  'j.',
#  'm.',
#  'attorneys',
#  'property',
#  'agreed',
#  'upon',
#  'listed',
#  "mayor's",
#  'occupation',
#  'attorney',
#  'age',
#  'birth',
#  'ala.',
#  'lived',
#  'together',
#  'man',
#  'more',
#  'than',
#  'year',
#  'home',
#  'e.',
#  'pelham',
#  'aj',
#  'henry',
#  'l.',
#  'brief',
#  'since',
#  'career',
#  'goes',
#  'back',
#  'council',
#  'present',
#  'he',
#  'succeeded',
#  'who',
#  'became',
#  'candidate',
#  'sept.',
#  '13',
#  'after',
#  'announced',
#  'would',
#  'run',
#  'georgia',
#  'republicans',
#  'getting',
#  'strong',
#  'encouragement',
#  'enter',
#  '1962',
#  "governor's",
#  'race',
#  'top',
#  'official',
#  'wednesday',
#  'robert',
#  'gop',
#  'chairman',
#  'meeting',
#  'held',
#  'tuesday',
#  'blue',
#  'ridge',
#  'brought',
#  'enthusiastic',
#  'audience',
#  'party',
#  'james',
#  'w.',
#  'enthusiasm',
#  'up',
#  'rally',
#  '8',
#  'newly',
#  'texas',
#  'sen.',
#  'john',
#  'speaker',
#  'warned',
#  'entering',
#  'governor',
#  'force',
#  'petitions',
#  'out',
#  'voting',
#  'obtain',
#  'signatures',
#  'registered',
#  'despite',
#  'warning',
#  'vote',
#  'according',
#  'attended',
#  'crowd',
#  'asked',
#  'whether',
#  'wanted',
#  'wait',
#  'make',
#  'voted',
#  '--',
#  'were',
#  'largest',
#  'face',
#  'says',
#  'before',
#  'making',
#  'first',
#  'alternative',
#  'courses',
#  'must',
#  'taken',
#  'five',
#  'per',
#  'cent',
#  'each',
#  'sign',
#  'allowed',
#  'names',
#  'candidates',
#  'ballot',
#  'hold',
#  'unit',
#  'system',
#  'sam',
#  'highway',
#  'public',
#  'relations',
#  'director',
#  'resigned',
#  'gov.',
#  'garland',
#  'campaign',
#  'resignation',
#  'expected',
#  'time',
#  'assistant',
#  'three',
#  'years',
#  'gubernatorial',
#  'starts',
#  'become',
#  'coordinator',
#  'wind',
#  '1961',
#  'session',
#  'monday',
#  'head',
#  'where',
#  'bond',
#  'approved',
#  'shortly',
#  'afternoon',
#  'senate',
#  'approve',
#  'study',
#  'rural',
#  'urban',
#  'areas',
#  'determine',
#  'what',
#  'made',
#  'vandiver',
#  'traditional',
#  'visit',
#  'toward',
#  'likely',
#  'mention',
#  '$100',
#  'million',
#  'issue',
#  'earlier',
#  'priority',
#  'item',
#  'construction',
#  'bonds',
#  'meanwhile',
#  'learned',
#  'very',
#  'near',
#  'being',
#  'ready',
#  'worth',
#  'go',
#  'courts',
#  'friendly',
#  'test',
#  'then',
#  'sales',
#  'begin',
#  'contracts',
#  'let',
#  'most',
#  'heavily',
#  'highways',
#  'source',
#  'roads',
#  'authority',
#  'road',
#  'fund',
#  'apparently',
#  'issued',
#  'every',
#  'old',
#  'ones',
#  'paid',
#  'off',
#  'authorities',
#  'opened',
#  '1958',
#  'battle',
#  'against',
#  'told',
#  'constitution',
#  'consulted',
#  'yet',
#  'about',
#  'plans',
#  'rep.',
#  'd.',
#  'offer',
#  'resolution',
#  'house',
#  'action',
#  'itself',
#  'day',
#  'increase',
#  'expense',
#  'sunday',
#  'research',
#  'done',
#  'can',
#  'outright',
#  'notice',
#  'given',
#  'sought',
#  'while',
#  'technical',
#  'details',
#  'fully',
#  'worked',
#  'seek',
#  'set',
#  'aside',
#  'privilege',
#  'similar',
#  'passed',
#  'word',
#  'offered',
#  'pointed',
#  'last',
#  'november',
#  'rejected',
#  'constitutional',
#  'amendment',
#  'allow',
#  'pay',
#  'sessions',
#  'veteran',
#  'jackson',
#  'aid',
#  'education',
#  'something',
#  'consistently',
#  'opposed',
#  'past',
#  'barber',
#  'commerce',
#  'asking',
#  'increased',
#  'support',
#  'provided',
#  '13th',
#  'members',
#  'congressional',
#  'washington',
#  'like',
#  'see',
#  'specifically',
#  'him',
#  'formally',
#  'read',
#  'event',
#  'congress',
#  'does',
#  'board',
#  'directed',
#  'give',
#  'teacher',
#  'long',
#  'hot',
#  'controversy',
#  'miller',
#  'school',
#  'superintendent',
#  'put',
#  'i',
#  'ever',
#  'saw',
#  'harry',
#  'davis',
#  'agriculture',
#  'defeated',
#  'principal',
#  'democratic',
#  'votes',
#  'got',
#  'ordinary',
#  'carey',
#  'armed',
#  'stood',
#  'polls',
#  'insure',
#  'order',
#  'tom',
#  'just',
#  'church',
#  "didn't",
#  'smell',
#  'drop',
#  'liquor',
#  'bit',
#  'trouble',
#  'leading',
#  'quiet',
#  'marked',
#  'anonymous',
#  'midnight',
#  'phone',
#  'calls',
#  'violence',
#  'former',
#  'george',
#  'p.',
#  'shot',
#  'himself',
#  'death',
#  'march',
#  '18',
#  'days',
#  'post',
#  'dispute',
#  'during',
#  'reportedly',
#  'telephone',
#  'too',
#  'subjected',
#  'soon',
#  'scheduled',
#  'local',
#  'carry',
#  'gun',
#  'promised',
#  'sheriff',
#  'good',
#  'promise',
#  'everything',
#  'went',
#  'real',
#  "wasn't",
#  'austin',
#  'approval',
#  'price',
#  'abandoned',
#  'seemed',
#  'certain',
#  'thursday',
#  'bankers',
#  'daniel',
#  'personally',
#  'led',
#  'fight',
#  'measure',
#  'down',
#  'considerably',
#  'rejection',
#  'hearing',
#  'revenue',
#  'taxation',
#  'rules',
#  'week',
#  'questions',
#  'appearing',
#  'witnesses',
#  'left',
#  'little',
#  'doubt',
#  'recommend',
#  'passage',
#  'termed',
#  'extremely',
#  'conservative',
#  'estimate',
#  'produce',
#  '17',
#  'dollars',
#  'help',
#  'anticipated',
#  'deficit',
#  'current',
#  'fiscal',
#  '31',
#  'merely',
#  'means',
#  'books',
#  'republic',
#  'over',
#  'bank',
#  'accounts',
#  'stocks',
#  'personal',
#  'persons',
#  'missing',
#  'seven',
#  'bill',
#  'banks',
#  'insurance',
#  'firms',
#  'companies',
#  'report',
#  'treasurer',
#  'cannot',
#  'enforced',
#  'now',
#  'because',
#  'almost',
#  'impossible',
#  'declared',
#  'lawrence',
#  'lawyer',
#  'representing',
#  'opposition',
#  'their',
#  'obligations',
#  'confidence',
#  'customers',
#  'if',
#  'you',
#  'destroy',
#  'economy',
#  'circulation',
#  'millions',
#  'charles',
#  'hughes',
#  'sherman',
#  'sponsor',
#  'amount',
#  'gift',
#  'denied',
#  'several',
#  'including',
#  'jones',
#  'houston',
#  'howard',
#  'argued',
#  'probably',
#  'enough',
#  'introduced',
#  'senators',
#  'parkhouse',
#  'dallas',
#  'schools',
#  'deaf',
#  'designed',
#  'special',
#  'students',
#  'reduced',
#  'debate',
#  'agency',
#  'establish',
#  'population',
#  'require',
#  'children',
#  'between',
#  '6',
#  'attend',
#  'older',
#  'residential',
#  'here',
#  'budget',
#  'harris',
#  'el',
#  'paso',
#  'savings',
#  'yearly',
#  "year's",
#  'capital',
#  'absorbed',
#  'tea',
#  'estimated',
#  'saving',
#  'coming',
#  'live',
#  'get',
#  'hear',
#  'horse',
#  'v.',
#  'red',
#  'joe',
#  'still',
#  'expects',
#  'tell',
#  'why',
#  'thinks',
#  "we're",
#  "'",
#  'pro',
#  'letters',
#  'believe',
#  'people',
#  'better',
#  'informed',
#  'question',
#  'oppose',
#  "i'm",
#  'willing',
#  'my',
#  'san',
#  'heard',
#  'proposal',
#  'favorable',
#  'although',
#  'faces',
#  'hard',
#  'later',
#  'finally',
#  'sent',
#  'extending',
#  'planning',
#  'cities',
#  'quickly',
#  'bills',
#  'committees',
#  'passing',
#  'calendar',
#  'acts',
#  'districts',
#  'another',
#  'district',
#  'third',
#  'creation',
#  'previously',
#  'adopted',
#  'without',
#  'a.',
#  'r.',
#  'mentally',
#  'retarded',
#  'gulf',
#  'coast',
#  'accept',
#  'site',
#  'revision',
#  'louis',
#  'group',
#  'taxes',
#  'eliminating',
#  'return',
#  'instead',
#  'penalty',
#  'plus',
#  'fine',
#  'series',
#  'league',
#  'paris',
#  'estate',
#  'own',
#  'annual',
#  'fee',
#  'license',
#  'natural',
#  'gas',
#  'utility',
#  'right',
#  'frank',
#  '3',
#  'marshall',
#  'commission',
#  'suggested',
#  'fill',
#  'need',
#  'costly',
#  'elections',
#  'selected',
#  'composed',
#  'chief',
#  'justice',
#  'supreme',
#  'representatives',
#  'decided',
#  'taking',
#  'poll',
#  'kind',
#  'texans',
#  '65',
#  'kept',
#  'affairs',
#  'april',
#  '4',
#  'u.s.',
#  'senator',
#  'idea',
#  'delay',
#  'west',
#  'reported',
#  'feb.',
#  '22',
#  'final',
#  'legislative',
#  'two-thirds',
#  'printed',
#  'opponents',
#  "couldn't",
#  'information',
#  'proposals',
#  'intelligent',
#  'choice',
#  'except',
#  'lost',
#  'water',
#  'needs',
#  'big',
#  'insisted',
#  'development',
#  'effort',
#  'fort',
#  'cover',
#  'places',
#  'ended',
#  'sending',
#  'sponsored',
#  'maximum',
#  'loan',
#  'could',
#  'project',
#  'large',
#  'felt',
#  'spent',
#  'providing',
#  'statements',
#  'paying',
#  'benefit',
#  'attack',
#  'mostly',
#  'de',
#  'la',
#  'mission',
#  'f.',
#  'collins',
#  'chapman',
#  'poor',
#  'serving',
#  'reducing',
#  'learning',
#  'educational',
#  'methods',
#  'c.',
#  'history',
#  '24',
#  '12',
#  'hours',
#  'so-called',
#  'teaching',
#  'required',
#  'junior',
#  'senior',
#  'high',
#  'normal',
#  'college',
#  '30',
#  'teachers',
#  'least',
#  'credit',
#  'subject',
#  'remainder',
#  'subjects',
#  'person',
#  'degree',
#  'english',
#  'permitted',
#  'teach',
#  'immediately',
#  'joined',
#  'named',
#  'dr.',
#  'clark',
#  'president',
#  'succeed',
#  'close',
#  'holds',
#  'earned',
#  'university',
#  'oklahoma',
#  'master',
#  'science',
#  '&',
#  'addition',
#  'rhode',
#  'island',
#  'massachusetts',
#  'institute',
#  'technology',
#  'captain',
#  'basketball',
#  'team',
#  'football',
#  'served',
#  'associate',
#  'professor',
#  'border',
#  'patrolman',
#  'signal',
#  ...]

# %%
vocab_index = map_index(vocab)
vocab_index
# Out:
# {'OOV': 0,
#  'the': 1,
#  'fulton': 2,
#  'county': 3,
#  'grand': 4,
#  'jury': 5,
#  'said': 6,
#  'friday': 7,
#  'an': 8,
#  'investigation': 9,
#  'of': 10,
#  'recent': 11,
#  'primary': 12,
#  'election': 13,
#  'produced': 14,
#  '``': 15,
#  'no': 16,
#  'evidence': 17,
#  "''": 18,
#  'that': 19,
#  'any': 20,
#  'took': 21,
#  'place': 22,
#  '.': 23,
#  'further': 24,
#  'in': 25,
#  'city': 26,
#  'executive': 27,
#  'committee': 28,
#  ',': 29,
#  'which': 30,
#  'had': 31,
#  'over-all': 32,
#  'charge': 33,
#  'deserves': 34,
#  'praise': 35,
#  'and': 36,
#  'thanks': 37,
#  'atlanta': 38,
#  'for': 39,
#  'manner': 40,
#  'was': 41,
#  'conducted': 42,
#  'term': 43,
#  'been': 44,
#  'charged': 45,
#  'by': 46,
#  'superior': 47,
#  'court': 48,
#  'judge': 49,
#  'to': 50,
#  'reports': 51,
#  'possible': 52,
#  'won': 53,
#  'allen': 54,
#  'jr.': 55,
#  'only': 56,
#  'a': 57,
#  'relative': 58,
#  'such': 59,
#  'received': 60,
#  'considering': 61,
#  'widespread': 62,
#  'interest': 63,
#  'number': 64,
#  'voters': 65,
#  'size': 66,
#  'this': 67,
#  'it': 68,
#  'did': 69,
#  'find': 70,
#  'many': 71,
#  "georgia's": 72,
#  'laws': 73,
#  'are': 74,
#  'or': 75,
#  'inadequate': 76,
#  'often': 77,
#  'recommended': 78,
#  'legislators': 79,
#  'act': 80,
#  'have': 81,
#  'these': 82,
#  'studied': 83,
#  'revised': 84,
#  'end': 85,
#  'improving': 86,
#  'them': 87,
#  'commented': 88,
#  'on': 89,
#  'other': 90,
#  'among': 91,
#  'purchasing': 92,
#  'departments': 93,
#  'well': 94,
#  'follow': 95,
#  'generally': 96,
#  'accepted': 97,
#  'practices': 98,
#  'best': 99,
#  'both': 100,
#  'governments': 101,
#  'merger': 102,
#  'proposed': 103,
#  'however': 104,
#  'believes': 105,
#  'two': 106,
#  'offices': 107,
#  'should': 108,
#  'be': 109,
#  'combined': 110,
#  'achieve': 111,
#  'greater': 112,
#  'reduce': 113,
#  'cost': 114,
#  'administration': 115,
#  'department': 116,
#  'is': 117,
#  'lacking': 118,
#  'experienced': 119,
#  'clerical': 120,
#  'personnel': 121,
#  'as': 122,
#  'result': 123,
#  'policies': 124,
#  'urged': 125,
#  'take': 126,
#  'steps': 127,
#  'problem': 128,
#  'automobile': 129,
#  'title': 130,
#  'law': 131,
#  'also': 132,
#  'next': 133,
#  'legislature': 134,
#  'provide': 135,
#  'enabling': 136,
#  'funds': 137,
#  'effective': 138,
#  'date': 139,
#  'so': 140,
#  'orderly': 141,
#  'may': 142,
#  'at': 143,
#  'state': 144,
#  'welfare': 145,
#  'federal': 146,
#  'granted': 147,
#  'child': 148,
#  'services': 149,
#  'homes': 150,
#  'one': 151,
#  'major': 152,
#  'items': 153,
#  'general': 154,
#  'assistance': 155,
#  'program': 156,
#  'but': 157,
#  'has': 158,
#  'seen': 159,
#  'fit': 160,
#  'through': 161,
#  'all': 162,
#  'counties': 163,
#  'with': 164,
#  'exception': 165,
#  'receives': 166,
#  'none': 167,
#  'money': 168,
#  'they': 169,
#  'realize': 170,
#  'distribution': 171,
#  'might': 172,
#  'our': 173,
#  'less': 174,
#  'nevertheless': 175,
#  'we': 176,
#  'feel': 177,
#  'future': 178,
#  'receive': 179,
#  'some': 180,
#  'portion': 181,
#  'available': 182,
#  'failure': 183,
#  'do': 184,
#  'will': 185,
#  'continue': 186,
#  'burden': 187,
#  'taxpayers': 188,
#  'under': 189,
#  'fire': 190,
#  'its': 191,
#  'appointment': 192,
#  'fees': 193,
#  'compensation': 194,
#  'protected': 195,
#  'found': 196,
#  'into': 197,
#  'operating': 198,
#  'procedures': 199,
#  'recommendations': 200,
#  'previous': 201,
#  'bar': 202,
#  'association': 203,
#  'citizens': 204,
#  'actions': 205,
#  'serve': 206,
#  'protect': 207,
#  'fact': 208,
#  'effect': 209,
#  'from': 210,
#  'costs': 211,
#  'appointed': 212,
#  'elected': 213,
#  'servants': 214,
#  'regarding': 215,
#  'new': 216,
#  'airport': 217,
#  'when': 218,
#  'management': 219,
#  'takes': 220,
#  'jan.': 221,
#  '1': 222,
#  'eliminate': 223,
#  'political': 224,
#  'not': 225,
#  'elaborate': 226,
#  'added': 227,
#  'there': 228,
#  'purpose': 229,
#  'keeping': 230,
#  'prices': 231,
#  'reasonable': 232,
#  'ask': 233,
#  'jail': 234,
#  'deputies': 235,
#  'matters': 236,
#  ':': 237,
#  '(': 238,
#  ')': 239,
#  'four': 240,
#  'additional': 241,
#  'employed': 242,
#  'doctor': 243,
#  'medical': 244,
#  'night': 245,
#  'weekend': 246,
#  'duty': 247,
#  '2': 248,
#  'work': 249,
#  'officials': 250,
#  'pass': 251,
#  'legislation': 252,
#  'permit': 253,
#  'establishment': 254,
#  'fair': 255,
#  'pension': 256,
#  'plan': 257,
#  'employes': 258,
#  'praised': 259,
#  'operation': 260,
#  'police': 261,
#  'tax': 262,
#  'office': 263,
#  'prison': 264,
#  'grady': 265,
#  'hospital': 266,
#  'health': 267,
#  'mayor': 268,
#  'william': 269,
#  'b.': 270,
#  'hartsfield': 271,
#  'filed': 272,
#  'suit': 273,
#  'divorce': 274,
#  'his': 275,
#  'wife': 276,
#  'pearl': 277,
#  'williams': 278,
#  'petition': 279,
#  'mental': 280,
#  'couple': 281,
#  'married': 282,
#  'aug.': 283,
#  'son': 284,
#  'berry': 285,
#  'daughter': 286,
#  'mrs.': 287,
#  'j.': 288,
#  'm.': 289,
#  'attorneys': 290,
#  'property': 291,
#  'agreed': 292,
#  'upon': 293,
#  'listed': 294,
#  "mayor's": 295,
#  'occupation': 296,
#  'attorney': 297,
#  'age': 298,
#  'birth': 299,
#  'ala.': 300,
#  'lived': 301,
#  'together': 302,
#  'man': 303,
#  'more': 304,
#  'than': 305,
#  'year': 306,
#  'home': 307,
#  'e.': 308,
#  'pelham': 309,
#  'aj': 310,
#  'henry': 311,
#  'l.': 312,
#  'brief': 313,
#  'since': 314,
#  'career': 315,
#  'goes': 316,
#  'back': 317,
#  'council': 318,
#  'present': 319,
#  'he': 320,
#  'succeeded': 321,
#  'who': 322,
#  'became': 323,
#  'candidate': 324,
#  'sept.': 325,
#  '13': 326,
#  'after': 327,
#  'announced': 328,
#  'would': 329,
#  'run': 330,
#  'georgia': 331,
#  'republicans': 332,
#  'getting': 333,
#  'strong': 334,
#  'encouragement': 335,
#  'enter': 336,
#  '1962': 337,
#  "governor's": 338,
#  'race': 339,
#  'top': 340,
#  'official': 341,
#  'wednesday': 342,
#  'robert': 343,
#  'gop': 344,
#  'chairman': 345,
#  'meeting': 346,
#  'held': 347,
#  'tuesday': 348,
#  'blue': 349,
#  'ridge': 350,
#  'brought': 351,
#  'enthusiastic': 352,
#  'audience': 353,
#  'party': 354,
#  'james': 355,
#  'w.': 356,
#  'enthusiasm': 357,
#  'up': 358,
#  'rally': 359,
#  '8': 360,
#  'newly': 361,
#  'texas': 362,
#  'sen.': 363,
#  'john': 364,
#  'speaker': 365,
#  'warned': 366,
#  'entering': 367,
#  'governor': 368,
#  'force': 369,
#  'petitions': 370,
#  'out': 371,
#  'voting': 372,
#  'obtain': 373,
#  'signatures': 374,
#  'registered': 375,
#  'despite': 376,
#  'warning': 377,
#  'vote': 378,
#  'according': 379,
#  'attended': 380,
#  'crowd': 381,
#  'asked': 382,
#  'whether': 383,
#  'wanted': 384,
#  'wait': 385,
#  'make': 386,
#  'voted': 387,
#  '--': 388,
#  'were': 389,
#  'largest': 390,
#  'face': 391,
#  'says': 392,
#  'before': 393,
#  'making': 394,
#  'first': 395,
#  'alternative': 396,
#  'courses': 397,
#  'must': 398,
#  'taken': 399,
#  'five': 400,
#  'per': 401,
#  'cent': 402,
#  'each': 403,
#  'sign': 404,
#  'allowed': 405,
#  'names': 406,
#  'candidates': 407,
#  'ballot': 408,
#  'hold': 409,
#  'unit': 410,
#  'system': 411,
#  'sam': 412,
#  'highway': 413,
#  'public': 414,
#  'relations': 415,
#  'director': 416,
#  'resigned': 417,
#  'gov.': 418,
#  'garland': 419,
#  'campaign': 420,
#  'resignation': 421,
#  'expected': 422,
#  'time': 423,
#  'assistant': 424,
#  'three': 425,
#  'years': 426,
#  'gubernatorial': 427,
#  'starts': 428,
#  'become': 429,
#  'coordinator': 430,
#  'wind': 431,
#  '1961': 432,
#  'session': 433,
#  'monday': 434,
#  'head': 435,
#  'where': 436,
#  'bond': 437,
#  'approved': 438,
#  'shortly': 439,
#  'afternoon': 440,
#  'senate': 441,
#  'approve': 442,
#  'study': 443,
#  'rural': 444,
#  'urban': 445,
#  'areas': 446,
#  'determine': 447,
#  'what': 448,
#  'made': 449,
#  'vandiver': 450,
#  'traditional': 451,
#  'visit': 452,
#  'toward': 453,
#  'likely': 454,
#  'mention': 455,
#  '$100': 456,
#  'million': 457,
#  'issue': 458,
#  'earlier': 459,
#  'priority': 460,
#  'item': 461,
#  'construction': 462,
#  'bonds': 463,
#  'meanwhile': 464,
#  'learned': 465,
#  'very': 466,
#  'near': 467,
#  'being': 468,
#  'ready': 469,
#  'worth': 470,
#  'go': 471,
#  'courts': 472,
#  'friendly': 473,
#  'test': 474,
#  'then': 475,
#  'sales': 476,
#  'begin': 477,
#  'contracts': 478,
#  'let': 479,
#  'most': 480,
#  'heavily': 481,
#  'highways': 482,
#  'source': 483,
#  'roads': 484,
#  'authority': 485,
#  'road': 486,
#  'fund': 487,
#  'apparently': 488,
#  'issued': 489,
#  'every': 490,
#  'old': 491,
#  'ones': 492,
#  'paid': 493,
#  'off': 494,
#  'authorities': 495,
#  'opened': 496,
#  '1958': 497,
#  'battle': 498,
#  'against': 499,
#  'told': 500,
#  'constitution': 501,
#  'consulted': 502,
#  'yet': 503,
#  'about': 504,
#  'plans': 505,
#  'rep.': 506,
#  'd.': 507,
#  'offer': 508,
#  'resolution': 509,
#  'house': 510,
#  'action': 511,
#  'itself': 512,
#  'day': 513,
#  'increase': 514,
#  'expense': 515,
#  'sunday': 516,
#  'research': 517,
#  'done': 518,
#  'can': 519,
#  'outright': 520,
#  'notice': 521,
#  'given': 522,
#  'sought': 523,
#  'while': 524,
#  'technical': 525,
#  'details': 526,
#  'fully': 527,
#  'worked': 528,
#  'seek': 529,
#  'set': 530,
#  'aside': 531,
#  'privilege': 532,
#  'similar': 533,
#  'passed': 534,
#  'word': 535,
#  'offered': 536,
#  'pointed': 537,
#  'last': 538,
#  'november': 539,
#  'rejected': 540,
#  'constitutional': 541,
#  'amendment': 542,
#  'allow': 543,
#  'pay': 544,
#  'sessions': 545,
#  'veteran': 546,
#  'jackson': 547,
#  'aid': 548,
#  'education': 549,
#  'something': 550,
#  'consistently': 551,
#  'opposed': 552,
#  'past': 553,
#  'barber': 554,
#  'commerce': 555,
#  'asking': 556,
#  'increased': 557,
#  'support': 558,
#  'provided': 559,
#  '13th': 560,
#  'members': 561,
#  'congressional': 562,
#  'washington': 563,
#  'like': 564,
#  'see': 565,
#  'specifically': 566,
#  'him': 567,
#  'formally': 568,
#  'read': 569,
#  'event': 570,
#  'congress': 571,
#  'does': 572,
#  'board': 573,
#  'directed': 574,
#  'give': 575,
#  'teacher': 576,
#  'long': 577,
#  'hot': 578,
#  'controversy': 579,
#  'miller': 580,
#  'school': 581,
#  'superintendent': 582,
#  'put': 583,
#  'i': 584,
#  'ever': 585,
#  'saw': 586,
#  'harry': 587,
#  'davis': 588,
#  'agriculture': 589,
#  'defeated': 590,
#  'principal': 591,
#  'democratic': 592,
#  'votes': 593,
#  'got': 594,
#  'ordinary': 595,
#  'carey': 596,
#  'armed': 597,
#  'stood': 598,
#  'polls': 599,
#  'insure': 600,
#  'order': 601,
#  'tom': 602,
#  'just': 603,
#  'church': 604,
#  "didn't": 605,
#  'smell': 606,
#  'drop': 607,
#  'liquor': 608,
#  'bit': 609,
#  'trouble': 610,
#  'leading': 611,
#  'quiet': 612,
#  'marked': 613,
#  'anonymous': 614,
#  'midnight': 615,
#  'phone': 616,
#  'calls': 617,
#  'violence': 618,
#  'former': 619,
#  'george': 620,
#  'p.': 621,
#  'shot': 622,
#  'himself': 623,
#  'death': 624,
#  'march': 625,
#  '18': 626,
#  'days': 627,
#  'post': 628,
#  'dispute': 629,
#  'during': 630,
#  'reportedly': 631,
#  'telephone': 632,
#  'too': 633,
#  'subjected': 634,
#  'soon': 635,
#  'scheduled': 636,
#  'local': 637,
#  'carry': 638,
#  'gun': 639,
#  'promised': 640,
#  'sheriff': 641,
#  'good': 642,
#  'promise': 643,
#  'everything': 644,
#  'went': 645,
#  'real': 646,
#  "wasn't": 647,
#  'austin': 648,
#  'approval': 649,
#  'price': 650,
#  'abandoned': 651,
#  'seemed': 652,
#  'certain': 653,
#  'thursday': 654,
#  'bankers': 655,
#  'daniel': 656,
#  'personally': 657,
#  'led': 658,
#  'fight': 659,
#  'measure': 660,
#  'down': 661,
#  'considerably': 662,
#  'rejection': 663,
#  'hearing': 664,
#  'revenue': 665,
#  'taxation': 666,
#  'rules': 667,
#  'week': 668,
#  'questions': 669,
#  'appearing': 670,
#  'witnesses': 671,
#  'left': 672,
#  'little': 673,
#  'doubt': 674,
#  'recommend': 675,
#  'passage': 676,
#  'termed': 677,
#  'extremely': 678,
#  'conservative': 679,
#  'estimate': 680,
#  'produce': 681,
#  '17': 682,
#  'dollars': 683,
#  'help': 684,
#  'anticipated': 685,
#  'deficit': 686,
#  'current': 687,
#  'fiscal': 688,
#  '31': 689,
#  'merely': 690,
#  'means': 691,
#  'books': 692,
#  'republic': 693,
#  'over': 694,
#  'bank': 695,
#  'accounts': 696,
#  'stocks': 697,
#  'personal': 698,
#  'persons': 699,
#  'missing': 700,
#  'seven': 701,
#  'bill': 702,
#  'banks': 703,
#  'insurance': 704,
#  'firms': 705,
#  'companies': 706,
#  'report': 707,
#  'treasurer': 708,
#  'cannot': 709,
#  'enforced': 710,
#  'now': 711,
#  'because': 712,
#  'almost': 713,
#  'impossible': 714,
#  'declared': 715,
#  'lawrence': 716,
#  'lawyer': 717,
#  'representing': 718,
#  'opposition': 719,
#  'their': 720,
#  'obligations': 721,
#  'confidence': 722,
#  'customers': 723,
#  'if': 724,
#  'you': 725,
#  'destroy': 726,
#  'economy': 727,
#  'circulation': 728,
#  'millions': 729,
#  'charles': 730,
#  'hughes': 731,
#  'sherman': 732,
#  'sponsor': 733,
#  'amount': 734,
#  'gift': 735,
#  'denied': 736,
#  'several': 737,
#  'including': 738,
#  'jones': 739,
#  'houston': 740,
#  'howard': 741,
#  'argued': 742,
#  'probably': 743,
#  'enough': 744,
#  'introduced': 745,
#  'senators': 746,
#  'parkhouse': 747,
#  'dallas': 748,
#  'schools': 749,
#  'deaf': 750,
#  'designed': 751,
#  'special': 752,
#  'students': 753,
#  'reduced': 754,
#  'debate': 755,
#  'agency': 756,
#  'establish': 757,
#  'population': 758,
#  'require': 759,
#  'children': 760,
#  'between': 761,
#  '6': 762,
#  'attend': 763,
#  'older': 764,
#  'residential': 765,
#  'here': 766,
#  'budget': 767,
#  'harris': 768,
#  'el': 769,
#  'paso': 770,
#  'savings': 771,
#  'yearly': 772,
#  "year's": 773,
#  'capital': 774,
#  'absorbed': 775,
#  'tea': 776,
#  'estimated': 777,
#  'saving': 778,
#  'coming': 779,
#  'live': 780,
#  'get': 781,
#  'hear': 782,
#  'horse': 783,
#  'v.': 784,
#  'red': 785,
#  'joe': 786,
#  'still': 787,
#  'expects': 788,
#  'tell': 789,
#  'why': 790,
#  'thinks': 791,
#  "we're": 792,
#  "'": 793,
#  'pro': 794,
#  'letters': 795,
#  'believe': 796,
#  'people': 797,
#  'better': 798,
#  'informed': 799,
#  'question': 800,
#  'oppose': 801,
#  "i'm": 802,
#  'willing': 803,
#  'my': 804,
#  'san': 805,
#  'heard': 806,
#  'proposal': 807,
#  'favorable': 808,
#  'although': 809,
#  'faces': 810,
#  'hard': 811,
#  'later': 812,
#  'finally': 813,
#  'sent': 814,
#  'extending': 815,
#  'planning': 816,
#  'cities': 817,
#  'quickly': 818,
#  'bills': 819,
#  'committees': 820,
#  'passing': 821,
#  'calendar': 822,
#  'acts': 823,
#  'districts': 824,
#  'another': 825,
#  'district': 826,
#  'third': 827,
#  'creation': 828,
#  'previously': 829,
#  'adopted': 830,
#  'without': 831,
#  'a.': 832,
#  'r.': 833,
#  'mentally': 834,
#  'retarded': 835,
#  'gulf': 836,
#  'coast': 837,
#  'accept': 838,
#  'site': 839,
#  'revision': 840,
#  'louis': 841,
#  'group': 842,
#  'taxes': 843,
#  'eliminating': 844,
#  'return': 845,
#  'instead': 846,
#  'penalty': 847,
#  'plus': 848,
#  'fine': 849,
#  'series': 850,
#  'league': 851,
#  'paris': 852,
#  'estate': 853,
#  'own': 854,
#  'annual': 855,
#  'fee': 856,
#  'license': 857,
#  'natural': 858,
#  'gas': 859,
#  'utility': 860,
#  'right': 861,
#  'frank': 862,
#  '3': 863,
#  'marshall': 864,
#  'commission': 865,
#  'suggested': 866,
#  'fill': 867,
#  'need': 868,
#  'costly': 869,
#  'elections': 870,
#  'selected': 871,
#  'composed': 872,
#  'chief': 873,
#  'justice': 874,
#  'supreme': 875,
#  'representatives': 876,
#  'decided': 877,
#  'taking': 878,
#  'poll': 879,
#  'kind': 880,
#  'texans': 881,
#  '65': 882,
#  'kept': 883,
#  'affairs': 884,
#  'april': 885,
#  '4': 886,
#  'u.s.': 887,
#  'senator': 888,
#  'idea': 889,
#  'delay': 890,
#  'west': 891,
#  'reported': 892,
#  'feb.': 893,
#  '22': 894,
#  'final': 895,
#  'legislative': 896,
#  'two-thirds': 897,
#  'printed': 898,
#  'opponents': 899,
#  "couldn't": 900,
#  'information': 901,
#  'proposals': 902,
#  'intelligent': 903,
#  'choice': 904,
#  'except': 905,
#  'lost': 906,
#  'water': 907,
#  'needs': 908,
#  'big': 909,
#  'insisted': 910,
#  'development': 911,
#  'effort': 912,
#  'fort': 913,
#  'cover': 914,
#  'places': 915,
#  'ended': 916,
#  'sending': 917,
#  'sponsored': 918,
#  'maximum': 919,
#  'loan': 920,
#  'could': 921,
#  'project': 922,
#  'large': 923,
#  'felt': 924,
#  'spent': 925,
#  'providing': 926,
#  'statements': 927,
#  'paying': 928,
#  'benefit': 929,
#  'attack': 930,
#  'mostly': 931,
#  'de': 932,
#  'la': 933,
#  'mission': 934,
#  'f.': 935,
#  'collins': 936,
#  'chapman': 937,
#  'poor': 938,
#  'serving': 939,
#  'reducing': 940,
#  'learning': 941,
#  'educational': 942,
#  'methods': 943,
#  'c.': 944,
#  'history': 945,
#  '24': 946,
#  '12': 947,
#  'hours': 948,
#  'so-called': 949,
#  'teaching': 950,
#  'required': 951,
#  'junior': 952,
#  'senior': 953,
#  'high': 954,
#  'normal': 955,
#  'college': 956,
#  '30': 957,
#  'teachers': 958,
#  'least': 959,
#  'credit': 960,
#  'subject': 961,
#  'remainder': 962,
#  'subjects': 963,
#  'person': 964,
#  'degree': 965,
#  'english': 966,
#  'permitted': 967,
#  'teach': 968,
#  'immediately': 969,
#  'joined': 970,
#  'named': 971,
#  'dr.': 972,
#  'clark': 973,
#  'president': 974,
#  'succeed': 975,
#  'close': 976,
#  'holds': 977,
#  'earned': 978,
#  'university': 979,
#  'oklahoma': 980,
#  'master': 981,
#  'science': 982,
#  '&': 983,
#  'addition': 984,
#  'rhode': 985,
#  'island': 986,
#  'massachusetts': 987,
#  'institute': 988,
#  'technology': 989,
#  'captain': 990,
#  'basketball': 991,
#  'team': 992,
#  'football': 993,
#  'served': 994,
#  'associate': 995,
#  'professor': 996,
#  'border': 997,
#  'patrolman': 998,
#  'signal': 999,
#  ...}

# %% [markdown]
# **Observation Matrix**

# %%
B=observation_matrix(corpus,map_pos_idx,vocab_index)
B
# Out:
# array([[1.55917534e-04, 5.34040001e-01, 3.89696411e-08, ...,
#         3.89696411e-08, 3.89696411e-08, 3.89696411e-08],
#        [2.19969606e-01, 6.08827969e-08, 6.08827969e-08, ...,
#         6.08827969e-08, 6.08827969e-08, 6.08827969e-08],
#        [3.78229117e-08, 3.78229117e-08, 3.78229117e-08, ...,
#         3.78229117e-08, 3.78229117e-08, 3.78229117e-08],
#        ...,
#        [2.88906502e-03, 1.44446029e-07, 1.44446029e-07, ...,
#         1.44446029e-07, 1.44446029e-07, 1.44446029e-07],
#        [8.97640426e-02, 1.05853699e-07, 1.05853699e-07, ...,
#         1.05853699e-07, 1.05853699e-07, 1.05853699e-07],
#        [1.32556422e-03, 3.68202056e-08, 3.68202056e-08, ...,
#         3.68202056e-08, 3.68202056e-08, 3.68202056e-08]])

# %% [markdown]
# **Viterbi Algorithm**

# %%
def viterbi(obs,pi,A,B):
    rows=len(pi)
    cols=len(obs)
    dp=[[0 for j in range(cols)] for i in range(rows)]
    state = [[0 for j in range(cols)] for i in range(rows)]
    for j in range(cols):
        for i in range(rows-1,-1,-1):
            if(j==0):
                dp[i][j]= pi[i]*B[i][obs[j]]
                state[i][j]= 0
            else:
                max_val=float('-inf')
                max_state =0
                for k in range(rows):
                    val = math.log(dp[k][j-1])+math.log(A[k][i])+math.log(B[i][obs[j]])
                    #print(val)
                    if(val>max_val):
                        max_val=val
                        max_state=k
               # print('next')
                state[i][j]=max_state
                dp[i][j]=math.exp(max_val)
    #print(dp)
    #print(state)
    max_val_last=float('-inf')
    best=0
    for i in range(rows):
        if(max_val_last<dp[i][cols-1]):
            max_val_last = dp[i][cols-1]
            states=[i]
            best=state[i][cols-1]
    for j in range(cols-2,-1,-1):
        states= [best]+states
        best = state[best][j]
        
    return states

# %% [markdown]
# **Inference**

# %%
test_data=nltk.corpus.brown.tagged_sents(tagset='universal')[10150:10153]
test_data
# Out:
# [[('Those', 'DET'),
#   ('coming', 'VERB'),
#   ('from', 'ADP'),
#   ('other', 'ADJ'),
#   ('denominations', 'NOUN'),
#   ('will', 'VERB'),
#   ('welcome', 'VERB'),
#   ('the', 'DET'),
#   ('opportunity', 'NOUN'),
#   ('to', 'PRT'),
#   ('become', 'VERB'),
#   ('informed', 'VERB'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('preparatory', 'ADJ'),
#   ('class', 'NOUN'),
#   ('is', 'VERB'),
#   ('an', 'DET'),
#   ('introductory', 'ADJ'),
#   ('face-to-face', 'ADJ'),
#   ('group', 'NOUN'),
#   ('in', 'ADP'),
#   ('which', 'DET'),
#   ('new', 'ADJ'),
#   ('members', 'NOUN'),
#   ('become', 'VERB'),
#   ('acquainted', 'VERB'),
#   ('with', 'ADP'),
#   ('one', 'NUM'),
#   ('another', 'DET'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('provides', 'VERB'),
#   ('a', 'DET'),
#   ('natural', 'ADJ'),
#   ('transition', 'NOUN'),
#   ('into', 'ADP'),
#   ('the', 'DET'),
#   ('life', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('local', 'ADJ'),
#   ('church', 'NOUN'),
#   ('and', 'CONJ'),
#   ('its', 'DET'),
#   ('organizations', 'NOUN'),
#   ('.', '.')]]

# %%
pi=createInitialMap(initial_state,all_POS)

# %%
obs =createobs(test_data,vocab_index)
obs
# Out:
# [[1200, 779, 210, 90, 0, 185, 3257, 1, 2017, 50, 429, 799, 23],
#  [1, 0, 3086, 117, 8, 0, 0, 842, 25, 30, 216, 561, 429, 0, 164, 151, 825, 23],
#  [68, 2095, 57, 858, 2296, 197, 1, 1892, 10, 1, 637, 604, 36, 191, 4157, 23]]

# %%
# Call the vitrbi algorithm for every test example
predicted =[]
for i in obs:
    result=viterbi(i,pi,A,B)
    sent_pred=[]
    for j in result:
        sent_pred.append(all_POS[j])
    predicted.append(sent_pred)

# %%
# Print the output in appropriate format
for idx,i in enumerate(test_data):
    actual_text=[]
    actual_pos=[]
    for j in i:
        actual_text.append(j[0])
        actual_pos.append(j[1])
    print("Actual Text")
    print(actual_text)
    print("Actual POS")
    print(actual_pos)
    print("Predicted POS")
    print(predicted[idx])
    print("")
# Out:
# Actual Text
# ['Those', 'coming', 'from', 'other', 'denominations', 'will', 'welcome', 'the', 'opportunity', 'to', 'become', 'informed', '.']
# Actual POS
# ['DET', 'VERB', 'ADP', 'ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'VERB', '.']
# Predicted POS
# ['DET', 'VERB', 'ADP', 'ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'VERB', '.']
#
# Actual Text
# ['The', 'preparatory', 'class', 'is', 'an', 'introductory', 'face-to-face', 'group', 'in', 'which', 'new', 'members', 'become', 'acquainted', 'with', 'one', 'another', '.']
# Actual POS
# ['DET', 'ADJ', 'NOUN', 'VERB', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NUM', 'DET', '.']
# Predicted POS
# ['DET', 'ADJ', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'NOUN', 'ADP', 'NUM', 'DET', '.']
#
# Actual Text
# ['It', 'provides', 'a', 'natural', 'transition', 'into', 'the', 'life', 'of', 'the', 'local', 'church', 'and', 'its', 'organizations', '.']
# Actual POS
# ['PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'CONJ', 'DET', 'NOUN', '.']
# Predicted POS
# ['PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'CONJ', 'DET', 'NOUN', '.']
