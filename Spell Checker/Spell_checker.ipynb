# %% [markdown]
# <h1>Created by: Vaishali Jain (vj52) and Vinayak Gupta (vg101) </h1>

# %%
from collections import Counter

# %%
def custom_tokeniser(text):
    """
        Takes input text as string and returns tokenised text as a list.
    """
    result = [text]
    for punc in ['.', ',', '\n', ' ', '\t','[',']', '(', ')', '{', '}',';', "'", '"', '-']:
        new_result = []
        for sentence in result:
            token_list = sentence.split(punc)
            first = True
            for token in token_list:
                if not first:
                    new_result.append(punc)
                else:
                    first = False
                new_result.append(token)
        result = new_result
    return result

# %%
def tokenized_data_counter(tokenized_data):
    """
        Takes tokenised text list as input and return a dict that provides frequency of each token.
    """
    counter = Counter(map(str.lower,tokenized_data))
    return dict(counter)

# %%
def get_vocab_set():
    """
        Gets the vocabulary set from the file.
    """
    vocab_set = set()
    with open('words_alpha.txt', 'r') as f:
        for line in f:
            vocab_set.add(line.strip())
    return vocab_set

# %%
def min_distance(word1, word2):
    """
        Calculates and returns the Levenshtein distance between 2 words
    """
    matrix= [[max(0,abs(j-i)) if(i==0 or j==0) else 0 for j in range(1+len(word2))] for i in range(1+len(word1))]
    for i in range(1,len(word1)+1):
        for j in range(1,len(word2)+1):
            sub_incr= 0 if word1[i-1]==word2[j-1] else 1
            matrix[i][j]= min(sub_incr+matrix[i-1][j-1], 1+min(matrix[i-1][j],matrix[i][j-1]))
    return matrix[len(word1)][len(word2)]

# %%
def find_among_best_words(best_words, tokenized_data_dict):
    """
        Finds the most commonly occuring word among the list of words with minimum Levensthein distance
    """
    best_word = best_words[0]
    freq = 0
    for word in best_words:
        if (word in tokenized_data_dict) and (tokenized_data_dict[word]>freq):
            freq = tokenized_data_dict[word]
            best_word = word
    return best_word

# %%
def find_min_distance_word(token,vocab_set,tokenized_input_counter):
    """
        Iterates through the dictionary to find the best word to replace the spelling mistake
    """
    min_dist=len(token)
    best_words=[]
    for vocab_word in vocab_set:
        if abs(len(token)-len(vocab_word))<=min_dist:
            curr_dist = min_distance(token.lower(),vocab_word.lower())
            if curr_dist<min_dist:
                min_dist=curr_dist
                best_words=[vocab_word]
            elif curr_dist==min_dist:
                best_words.append(vocab_word)
    return find_among_best_words(best_words, tokenized_input_counter)

# %%
def custom_detokeniser(token_list):
    """
        Performs detokenization by joining all the tokens
    """
    return "".join(token_list)

# %%
def spell_checker(input_data):
    """
        Performs tokenization, spell checking and detokenization by calling the appropriate functions
    """
    tokenized_input = custom_tokeniser(input_data)
    tokenized_input_counter = tokenized_data_counter(tokenized_input)
    vocab_set = get_vocab_set()
    dictionary={}
    tokenized_output=[]
    for token in tokenized_input:
        if (not token.isalpha()) or (token.lower() in vocab_set):
            tokenized_output.append(token)
        else:
            if token in dictionary:
                tokenized_output.append(dictionary[token])
            else:
                if len(token)>0 and (ord(token[0])>=97 and ord(token[0])<=122) or (ord(token[len(token)-1])<=90 and ord(token[len(token)-1])>=65): # starting with small letter or containing all capital letter
                    best_word = find_min_distance_word(token,vocab_set,tokenized_input_counter)
                    if ord(token[len(token)-1])<=90:
                        best_word=best_word.upper()
                    dictionary[token]=best_word
                    print(token, best_word)
                    tokenized_output.append(best_word)
                else: 
                    tokenized_output.append(token)

    output_data = custom_detokeniser(tokenized_output)
    return output_data

# %%
def get_input_text(filename):
    """
        Reads the input file from the filename specified
    """
    with open(filename, 'r') as file:
        data = file.read()
    return data

# %%
def write_output_text_to_file(output_text):
    """
        Writes string to an output file
    """
    text_file = open("austen-sense-corrected.txt", "wt")
    text_file.write(output_text)
    text_file.close()

# %%
input_file = 'austen-sense-corrupted.txt'
input_data = get_input_text(input_file)
output_data = spell_checker(input_data)
write_output_text_to_file(output_data)
# Out:
# CHAPOTER CHAPTER
# estete estate
# thfs this
# estat estate
# hijs his
# ryears years
# beore before
# fuor for
# gto to
# lodss loss
# eceivepd received
# inheritkr inheritor
# lperqson person
# wsom whom
# theoir their
# childrn children
# attacsment attachment
# consmant constant
# fom for
# hveart heart
# sorid solid
# relitsh relish
# hxs his
# yousg young
# fortunce fortune
# dms ms
# bhim him
# ojn on
# lestate estate
# forsunv forsung
# rmight might
# arlise arise
# fateer father
# teir their
# thousnd thousand
# wifl will
# wavs was
# fhild child
# okther other
# wsll will
# cmuch much
# seither neither
# ungrfteful ungrateful
# tvhe the
# hild child
# provcding providing
# whvo who
# carge care
# oxf of
# chilu child
# visis visit
# faather farther
# kother mother
# ffections affections
# attrayctions attractions
# yeabs years
# earneqt earnest
# hxis his
# unning running
# eal deal
# nof of
# valte value
# attentiuox attention
# reweived received
# howeer however
# affectdion affection
# thouswaund thousand
# disapvointment disappointment
# hys his
# chkerfjl cheerful
# sanguzne sanguine
# livve live
# tand and
# consideraqle considerable
# estte estate
# immediayte immediate
# tso to
# twemlvemonnth twelvemonth
# survixed survived
# tfn ten
# duxghters daughters
# dange danger
# whichh which
# ckomand command
# ahe the
# interesv interest
# sisbeers sisters
# recmmendation recommendation
# hio his
# comfortavble comfortable
# fther other
# therse there
# rhis his
# chearted hearted
# respectecd respected
# je be
# conductxed conducted
# propciety propriety
# ordinarx ordinary
# caricalture caricature
# xselfish selfish
# eqal equal
# addikion addition
# prjesent present
# heact heart
# enoug enough
# culd could
# lmttle little
# inconkenience inconvenience
# thouht thought
# successivefly successively
# tchan than
# ithout without
# hlr her
# intection intention
# motaher mother
# rrived arrived
# chilb child
# dispue dissue
# indilicacy indelicacy
# anfd and
# ther the
# aniy any
# dislust disgust
# haad had
# thdis this
# ungrvcious ungracious
# earnestl earnest
# deqposh depoh
# plaw law
# thaq that
# whe the
# quitzed quitted
# frst first
# projpriety propriety
# wll all
# determinid determined
# afterard afterward
# stbwy stewy
# qwith with
# elgdest eldest
# dazughter daughter
# uws us
# sko so
# effecoual effectual
# pssessed possessed
# counsello counsellor
# nabled enabled
# xll all
# tht the
# eecellent excellent
# affectonate affectionate
# feelsings feelings
# moher mother
# hbr her
# sistrs sisters
# taugt taught
# abiities abilities
# equawl equal
# lsorrogws sorrows
# modertion moderation
# amnable amiable
# reoemblance resemblance
# uer her
# anid and
# srikyingly strikingly
# sensibhlity sensibility
# cherishdd cherished
# encouraxged encouraged
# vioflence violence
# overowered overpowered
# rpenewed renewed
# themselfves themselves
# injcrease increase
# wretchredness wretchedness
# reflfection reflection
# consolatioh consolation
# herelf herself
# apnd and
# hepr her
# astentison attention
# strve serve
# mther mother
# siilar similar
# thu the
# othek other
# dfal deal
# rzomanca romanza
# havng having
# jbid bid
# HAPTER CHAPTER
# intalled installed
# herslf herself
# thve the
# civilipy civility
# husand husband
# ynybody anybody
# byond beyond
# hzimself himself
# mconsider consider
# eligixle eligible
# therq there
# remilded reminded
# eher her
# happnss happiness
# happtess happiness
# itsellf itself
# forrow sorrow
# awzay away
# fandcy fancy
# aut at
# impoverizshing impoverishing
# tpo to
# hiself himself
# sjo so
# caim calm
# fery very
# ruppose suppose
# chzldren children
# tjeir their
# atll all
# hpis his
# repliwd replied
# wwa wa
# fthing thing
# stfiplcte stipulate
# myhself myself
# tjought thought
# perforkmed performed
# setle settle
# LEIT LEFT
# tthousand thousand
# spe she
# onme one
# partbd parted
# witm with
# returjn return
# hwill will
# uto to
# diffrence difference
# hmay may
# instahnce instance
# vecy very
# diminshed diminished
# cbe be
# incrjease increase
# hraf haf
# evn even
# REAILY REALLY
# replierd replied
# muh much
# leay lay
# evef ever
# thegseves themselves
# hadly hardly
# thini think
# affxord afford
# tfo to
# additio addition
# minee mine
# pouns pounds
# deaxth death
# lfrtune fortune
# yobung young
# woma woman
# indevd indeed
# wanft want
# agll all
# dividd divide
# ampongst amongst
# thez the
# tthey they
# doinl doing
# wel we
# cgomfortably comfortably
# whzther whether
# upoln upon
# tmore more
# tjheir their
# crathekr rather
# fokr for
# woul would
# femel feel
# heself herself
# hyear hear
# woulwd would
# peirfectly perfectly
# litle little
# hundeed hundred
# yers yes
# nwar near
# dher her
# evehr ever
# fdart fart
# bustiness business
# thgere there
# rhave have
# sy s
# mlher her
# sedvants servants
# wila will
# ipt it
# waere were
# gecting getting
# afterwvards afterwards
# ous out
# qije time
# sicdk sick
# bwn own
# bbcause because
# woduld would
# hisosal disposal
# whatevex whatever
# hyas has
# pii pit
# dtwn down
# zrains grains
# sas was
# doewn down
# paymept payment
# gway away
# independeence independence
# secue secure
# yfu you
# nho no
# qbind bind
# inconvenzient inconvenient
# sbpare spare
# zrom from
# oujr our
# therte there
# zin in
# rwhatever whatever
# ccasionallzy occasionally
# yearlwy yearly
# tsey they
# enarge enarme
# fel felt
# duch such
# prtevent prevent
# tgeir their
# beiny being
# pkroxise promise
# yofur your
# thmuuht thought
# dafe dare
# sayy say
# hexlping helping
# hings things
# prsents presents
# stmrange strange
# zxcessively excessively
# hvr her
# aughters daughters
# ceven even
# pouuds pounds
# apounds pounds
# grels gaels
# xheir their
# mothear mother
# khave have
# pwomen women
# tpaa taa
# xwill will
# keew knew
# zhaze haze
# expnses expenses
# cannrt cannot
# bhalf half
# thinsk think
# hmore more
# YONU YOU
# peyfectly perfectly
# requst request
# asistace assistance
# kndness kindness
# remroves removes
# ervices services
# readly really
# ven even
# conidered considered
# ather other
# mfther mother
# aoed toed
# thoaugh though
# turniture furniture
# plale place
# jis his
# compltely completely
# matearial material
# valnable valuable
# ledacy legacy
# ybt yet
# smome some
# pleasanq pleasant
# cqhina china
# twic twice
# ivs is
# otu ot
# pto to
# decmsion decision
# CHATER CHAPTER
# moae more
# knowf know
# violient violent
# whilme while
# pirits spirits
# becapme became
# czpable capable
# snohe snoke
# othel other
# remembrancef remembrance
# remov remove
# besloved beloved
# mshe she
# txat that
# nce once
# ntions notions
# aind and
# suted suited
# steadiewr steadier
# tqheir their
# icome come
# wiich which
# xinformed informed
# olemn solemn
# romioe promise
# favouj favour
# whch which
# rteflections reflections
# voubted doubted
# dmore more
# duubted doubted
# ushe she
# cshe she
# tkhat that
# brcother brother
# sacke sake
# rejoicerd rejoiced
# anad and
# bevviour behaviour
# coxvinced convinced
# fkirmly firmly
# tre the
# ehis his
# whmch which
# verqy very
# daughbter daughter
# farter farther
# ldies ladies
# circumstgnrce circumstance
# occuwred occurred
# gimvae give
# mdaxughters daughters
# wls was
# dgrowing growing
# aattachmest attachment
# bgetween between
# ldest eldest
# gentliman gentleman
# wzas was
# establihment establishment
# hdad had
# timde time
# theie their
# dijed died
# mcght might
# przdence prudence
# triflinqg trifling
# frtune fortune
# onsfderateiro consideration
# appeartd appeared
# amiarle amiable
# lovrd loved
# ekery every
# differencge difference
# fortun fortune
# ascnder ascender
# rpesemblance resemblance
# meryit merit
# shoul should
# xwho who
# itheir their
# bthem them
# plepsving pleasing
# cndication indication
# affzeciionatc affectionate
# hekrt heart
# yitted fitted
# diposition disposition
# wkishes wishes
# tbo to
# wolld would
# potlitical political
# tio to
# thke the
# liewise likewise
# superieor superior
# blesskings blessings
# quited quite
# domestyc domestic
# comfor comfort
# llifye life
# stayinv staying
# muc much
# surrocnding surrounding
# chabnced chanced
# contrasdt contrast
# moswt most
# formcibly forcibly
# unlke unlike
# loyve love
# alreqdy already
# inor nor
# cknow know
# amore more
# sentimeng sentiment
# amcquainted acquainted
# reajlly really
# seooner sooner
# zdid did
# ove one
# marrlage marriage
# apidl apiol
# linor elinor
# wilb will
# lbut but
# wil will
# scarcelz scarcely
# separaktion separation
# omet met
# liveu live
# xhe the
# dirapprove disapprove
# lhere there
# somethig something
# eiyes eyes
# spzirit spirit
# nreal real
# adbmiyres admires
# vty vt
# noj not
# cwho who
# gbe be
# witf with
# wose whose
# everky every
# ntzr nor
# qmust must
# spirieless spiritless
# faelt felt
# ywith with
# mluch much
# beaputiful beautiful
# freuently frequently
# surch such
# cafmnes calmness
# cemrtainly certainly
# simpte simple
# aollow allow
# thereforze therefore
# vhappy happy
# wopld would
# whbm whom
# goodneps goodness
# sevenfteen seventeen
# lilfe life
# gf of
# fortunatae fortunate
# syour your
# zni ani
# CDAPTER CHAPTER
# haxve have
# ashe she
# tasnte taste
# pleaure pleasure
# perforimances performances
# tyaste taste
# learninl learning
# vgery very
# jaudgment judgment
# simpliciny simplicity
# rigut right
# uas was
# apprbation approbation
# ecited excited
# pefple people
# vry very
# thot that
# tast last
# smiliwng smiling
# mistakk mistake
# szister sister
# hich which
# jeficiennt deficient
# ou of
# sould could
# civuil civil
# feeljngs feelings
# ihf if
# nout not
# equa equal
# nhis his
# ymerts merits
# mwany many
# propenshhies propensities
# otf of
# worhy wormy
# vxparess express
# wrmly warmly
# pllased pleased
# hsis his
# xseen seen
# excellencfe excellence
# understandfing understanding
# nyseyf myself
# havse have
# gooy good
# engrojsed engrossed
# affectioate affectionate
# priniple principle
# zeen been
# stusied studied
# pkronounce pronounce
# boks books
# hius his
# dhis his
# rcountenancn countenance
# thinfk think
# yu you
# nonw now
# jimpergection imperfection
# rthan than
# kbelieved believed
# requied required
# qo to
# attacjhment attachment
# momen moment
# hto to
# expyain explain
# tase take
# nomt not
# ggreatly greatly
# buyrst burst
# indignatio indignation
# tose those
# amgain again
# mxe me
# sjid said
# asured assured
# heant heart
# speakiqg speaking
# fpelings feelings
# spch such
# meyrit merit
# dthe the
# susxpicion suspicion
# waorrant warrant
# hwithvout without
# wor for
# oby by
# rygard regard
# mooments moments
# qnd and
# hilg hill
# seiments segments
# knwn known
# qthere there
# qonsidered considered
# hiv his
# inclnation inclination
# kfrom from
# independnt independent
# toccasional occasional
# mentin mention
# bisposd disposed
# axnd and
# ahm am
# df of
# enot not
# leither neither
# fastonished astonished
# frind find
# imaginatioln imagination
# anld and
# engxaged engaged
# snon soon
# wrhat what
# favouritc favourite
# tzo to
# futurm future
# flicdinty felicity
# nshould should
# stmmulated stimulated
# leain learn
# himseljf himself
# delightjful delightful
# svate state
# indofference indifference
# unpromisxing unpromising
# suppoing supposing
# hiim him
# wbe be
# fryquently frequently
# attznded attended
# raasonable reasonable
# forbave forgave
# rto to
# comforsuable comfortable
# aay any
# thawt that
# witout without
# sbject subject
# frrom from
# cnertain certain
# togther together
# mopre more
# ieemed seemed
# ghe the
# dnature nature
# ythan than
# limis limbs
# ktime time
# stll still
# firnt first
# affroting affronting
# brothr brother
# xpectations expectations
# hrr her
# danygelr danger
# attendiong attending
# ttempted attempted
# neithir neither
# endeavovr endeavour
# mcalm calm
# lft left
# hresolving resolving
# whataver whatever
# bre be
# inconvenince inconvenience
# xpense expense
# xof of
# beldved beloved
# insinations insinuations
# particuarly particularly
# erms terms
# rgentleman gentleman
# etter better
# gentmeman gentleman
# aczcommodation accommodation
# aspsured assured
# wpich which
# necerssary necessary
# givig giving
# particulaws particulars
# dyaughters daughters
# plae place
# irom from
# whethr whether
# kouses houses
# samc same
# hqer her
# sewmed seemed
# aqcommodate accommodate
# hwis his
# bhas has
# kstyle style
# sufferijng suffering
# uxfeeling unfeeling
# delbibermtion deliberation
# inqiry inquiry
# fored forced
# behore before
# posibdle possible
# pxlace place
# ombject object
# blessin blessing
# comparion companion
# gueyt guest
# ainful painful
# winhabit inhabit
# sletters letters
# thaot that
# thught thought
# settule settle
# amonfgst amongst
# presett present
# heaad heard
# kot not
# mothwer mother
# intenton intention
# vnto into
# mescribed described
# modeate moderate
# obvjection objection
# eithher either
# frm from
# atempt attempt
# hersel herself
# tdhe the
# roidmd roiled
# tham that
# wre were
# inlhabiting inhabiting
# ohusband husband
# froqm from
# replyinb replying
# gthat that
# repeatd repeated
# irndeed indeed
# goincg going
# siluation situation
# cotage cottage
# orr or
# diffticulty difficulty
# trvelling travelling
# gav gave
# greter greater
# affction affection
# ano and
# lconger longer
# tenbed tended
# sefarate separate
# wishted wished
# pbrother brother
# isregarded disregarded
# disapprobatqon disapprobation
# fxo fo
# idn in
# xrmoving removing
# ov of
# fzr for
# vhic hic
# perfgrmance performance
# pomise promise
# faher father
# impracticblpe impracticable
# furnhiture furniture
# wih with
# iannofortte pianoforte
# hsaw saw
# depaxt depart
# trfling trifling
# wth with
# ihandsome handsome
# teok took
# tle the
# swe she
# onfly only
# fvor for
# hdr her
# jand and
# kousehold household
# exceedingl exceedingly
# eveything everything
# interestded interested
# iis his
# opkportunisty opportunity
# dispoing disposing
# zchildren children
# limitd limits
# inpto into
# theis their
# mistkress mistress
# arriar arrear
# cotmtage cottage
# visiqtor visitor
# relnied relied
# undobtingly undoubtingly
# hous house
# hrself herself
# etered entered
# tt to
# sthe the
# eviddent evident
# satisfathon satisfaction
# feedly feebly
# nitation nitration
# deplarture departure
# wafs was
# zis his
# neglced neglected
# ficst first
# cgming coming
# theqir their
# quirtting quitting
# hozse house
# micght might
# lookd look
# uitable suitable
# acomplishment accomplishment
# fover over
# flrom from
# thzir their
# frequentlz frequently
# perpmetual perpetual
# drelmands demands
# pulrse pulse
# worlzd world
# zxposed exposed
# qfirst first
# bgin begin
# shal shall
# knxow know
# hyiewing viewing
# frbm from
# ducay decay
# motiovnless motionless
# altjhough although
# chanxge change
# kwalk walk
# remapin remain
# uheir their
# melanchaoly melancholy
# teious tedious
# anj and
# upleasant pleasant
# cheerfhulness cheerfulness
# woodef wooded
# wndxing winding
# reachded reached
# thmeir their
# courk court
# whoole whole
# fmront front
# intpo into
# houqse house
# tqough though
# uilding building
# eere were
# ehind behind
# sixteben sixteen
# twhe the
# cnd and
# soovn soon
# driex drie
# ceered cered
# ahd and
# weach each
# oxhers others
# pwas was
# nas was
# seewing seeing
# pnlace place
# weahthher weather
# recived received
# whlch which
# ajprobation approbation
# igh sigh
# epach each
# suide side
# soxe some
# wondy pondy
# chiefld chiefly
# pleauant pleasant
# windnws windows
# exttensive extensive
# vaqlley valley
# nerminated germinated
# brached bached
# betweek between
# thqe the
# lftter letter
# ondispensable indispensable
# tmo to
# tenouegh enough
# prekent present
# ibt it
# fplenty plenty
# saty say
# smahl small
# lto to
# wn in
# havie have
# throzwing throwing
# passaghe passage
# idto into
# yf of
# ote one
# remaindnr remainder
# ith it
# adden added
# chagmber chamber
# aove love
# handsuome handsome
# thogh though
# woquld would
# accordingmly accordingly
# meman mean
# htime time
# frojm from
# uaved saved
# ig i
# bnough enough
# eacnh each
# bvsy busy
# opther other
# pianofoete pianoforte
# unpzacked unpacked
# ovf of
# ttheir their
# entranace entrance
# caled called
# welcsme welcome
# acscommodation accommodation
# owo own
# deficien deficient
# countenanc countenance
# gocd good
# seeme seemed
# ard and
# smolicitude solicitude
# wigh with
# rbetter better
# endtreaties entreaties
# carriqed carried
# persgverance perseverance
# beyhnd beyond
# civiliy civility
# gardemn garden
# aefore before
# presen present
# mornover moreover
# yhe the
# senduin sending
# iddleton middletone
# intcntion intention
# woulld would
# inconvnenience inconvenience
# invitagtion invitation
# polizte polite
# laadyship ladyship
# introducdd introduced
# neoxt next
# ty to
# comfodt comfort
# arppearance appearance
# niot not
# twent went
# addresys address
# waprmith warmth
# thougfh though
# perfectlsy perfectly
# nothin nothing
# hsrself herself
# plhace place
# cbatty chatty
# chld child
# abot about
# adies ladies
# adswered answered
# wnile while
# sxrprie surprise
# njoisee noise
# enqurgh enough
# prty party
# discorse discourse
# prysient present
# paticular particular
# fody body
# wbody body
# gziven given
# hhouse house
# securirg securing
# tze the
# froq from
# alonr alone
# vriew view
# prnojection projection
# haadsome handsome
# vowever however
# amnd and
# onfined confined
# sofiety society
# vand and
# childen children
# independtnt independent
# remployments employments
# onlsy only
# oalf half
# tihe the
# fngagements engagements
# gcod good
# ekleganc elegance
# fjrom from
# waz was
# youlg young
# alkl all
# prt put
# oef of
# doogs doors
# anv and
# winhter winter
# arrxval arrival
# crountry country
# wero were
# goocd good
# opinioz opinion
# friendlinss friendliness
# hituation situation
# zthe the
# ccousins cousins
# satisfction satisfaction
# heqart heart
# ipn in
# faily family
# sporltsman sportsman
# oznly only
# desirus desirous
# encouzrgng encouraging
# tahem them
# uaffected affected
# sncerity sincerity
# ladie ladies
# oung young
# frend friend
# neithqr neither
# exguye excuse
# cokuld could
# ishould should
# newver never
# aso as
# sbveral several
# rcurng rung
# somme some
# addiaion addition
# numbenr number
# mnonlight moonlight
# chebful cheeful
# agreeatle agreeable
# phoped hoped
# nont not
# oery very
# mght might
# satisied satisfied
# eldely elderly
# vey very
# laqghter laughter
# ydinner dinner
# husands husbands
# heawrts hearts
# ussex sussex
# oand and
# preitended pretended
# foar for
# sisxter sister
# hvw how
# attackns attacks
# earvestness earnestness
# friepd friend
# mander manner
# mothmr mother
# ilent silent
# siite spite
# absowute absolute
# wns was
# thowgh though
# wajs was
# insipidnty insipidity
# ias was
# grvity gravity
# hiqs his
# mpother mother
# oused used
# enoyment enjoyment
# weo who
# hceothes clothes
# wnd and
# whayt what
# muvical musical
# clharmed charmed
# whiclh which
# famtily family
# celerated celebrated
# accqount account
# wpll will
# hger her
# admration admiration
# mwghile while
# afrequently frequently
# oinly only
# reppect respect
# occasxon occasion
# estimabl estimably
# hrrible horrible
# wav was
# trhat that
# pirty party
# ight might
# feelng feeling
# hxumanity humanity
# QHAPTER CHAPTER
# thernefore therefore
# actve active
# nall all
# bacquaintance acquaintance
# discovxery discovery
# advanage advantage
# fhe the
# thue the
# ndy nd
# insiniations insinuations
# pewer power
# pronozunce pronounce
# viit visit
# asertaine ascertain
# excelent excellent
# cfnnection connection
# broughkt brought
# knowledgy knowledge
# prtty pretty
# avantagae avantage
# tj to
# wal was
# tncvonsiderabue inconsiderable
# djokes jokes
# azainst against
# athe the
# cjloel colonel
# himsel himself
# objct object
# cunderstood understood
# impehtinence impertinence
# onsideired considered
# unfleling unfeeling
# yars years
# exceebdingly exceedingly
# dto to
# rdicule ridicule
# leazst least
# abserdity absurdity
# dccusation accusation
# cerrtainly certainly
# denough enough
# evry every
# tco to
# wpt wit
# wilgl will
# calrl call
# thau that
# ccan can
# comlain complain
# declinig declining
# hehr her
# extendpd extended
# advauced advanced
# justce justice
# senough enough
# apprghensive apprehensive
# couarse course
# lougjr longer
# nodthing nothing
# maurimony matrimony
# hcave have
# wommn woman
# singfle single
# fivwe five
# arianne marianne
# aafection affection
# herselg herself
# lherefore therefore
# woudd would
# mce me
# wicshed wished
# wuld would
# impossable impossible
# qtwenty twenty
# coruld could
# acything anything
# snough enough
# musct must
# constlant constant
# confinemenrt confinement
# chamdber chamber
# yqesterday yesterday
# coxd cold
# feedl feel
# wistcioats waistcoats
# fsaid said
# invvriably invariably
# connnected connected
# ahes aches
# rheumatisms rheumatism
# tmhe the
# feebfle feeble
# vioenct violent
# ytu you
# ythe the
# flushged flushed
# holow hollow
# leapving leaving
# blarm alarm
# hhe the
# illnpss illness
# beern been
# doen down
# occnasion occasion
# ctan can
# oo to
# contrdary contrary
# havme have
# thait that
# readiess readiness
# ievitation invitation
# taxked talked
# buk but
# shle she
# whecn when
# talkidg talking
# tte the
# likly likely
# xhis his
# dqd did
# togebher together
# pof of
# jid did
# ollow allow
# eut but
# coommand command
# restljss restless
# dissacisfied dissatisfied
# witv with
# olerble tolerable
# cofot coft
# whicmh which
# clharms charms
# greate great
# enjoymebnt enjoyment
# akle able
# noet not
# hme he
# findiing finding
# emplooed employed
# emcept except
# enteaties entreaties
# neijhbourhood neighbourhood
# alwayl always
# spijit spirit
# thm the
# vallzy valley
# descibed described
# avcient ancient
# xrespectable respectable
# looving looking
# mansicn mansion
# litte little
# theiv their
# unfortunaftqely unfortunately
# itfirm infirm
# bezutiful beautiful
# walkus walks
# higf high
# wowns downs
# wrich which
# onf of
# thueir their
# eumrits summits
# beaiuties beauties
# memormable memorable
# cthe the
# pafrtial partial
# confinemeknt confinement
# bpook book
# declaradtion declaration
# iay may
# rtoghthser together
# gaihly gaily
# twe the
# glimse glimpse
# whekn when
# westerjly westerly
# thbir their
# delighetful delightful
# sepnsations sensations
# saoigd said
# superor superior
# tw to
# dhours hours
# xih xi
# deliiht delight
# minxutes minutes
# heasds heads
# tnhey they
# unbillinly unwillingly
# lhan than
# hjouse house
# exigelce exigence
# thg the
# sdep step
# tuddencly suddenly
# ayl all
# invountarily involuntarily
# anqd and
# cith with
# acnd and
# hwhen when
# hassistance assistance
# stanb stand
# offzered offered
# hgs his
# anvd and
# vdeclined declined
# endered entered
# wivhout without
# qand and
# lefat left
# hofuse house
# whuither whither
# rquitted quitted
# evient event
# whic which
# nqually equally
# sdrhung sprung
# froh from
# inmrusion intrusion
# graweful grateful
# cnarms charms
# ofrom from
# gratitudee gratitude
# belen been
# sscured secured
# aattentimon attention
# intzerest interest
# swetness sweetness
# heb her
# annd and
# whozm whom
# frwom from
# wulv wull
# jallow allow
# honotur honour
# callking calling
# toemorrow tomorrow
# gjated gated
# knd and
# gracefulnes gracefulness
# minstantly instantly
# eneral general
# rauised raised
# receied received
# spirnit spirit
# froo from
# exteio extent
# ttractions attractions
# hherself herself
# erson person
# ouver over
# facqe face
# regardidng regarding
# enogh enough
# evr ever
# drpaw draw
# beloneing belonging
# refsidence residence
# soown soon
# bewcoming becoming
# imaginatin imagination
# refluctions reflections
# sprined spined
# iwterval interval
# oul out
# acident accident
# eygerly eagerly
# gcried cried
# hmim him
# evuer ever
# asesure assure
# lhat that
# intiomaxte intimate
# ittle little
# blck back
# ouz out
# saisfy satisfy
# ponter porter
# yould could
# shavdes shades
# ineelligence intelligence
# anjd and
# vproperty property
# inherwit inherit
# herseln herself
# blelievfe believe
# vood good
# ttwards towards
# whbt what
# CATHING CATCHING
# lemployment employment
# whicz which
# hcwever however
# acquintance acquaintance
# emember remember
# cloxk clock
# elegangce elegance
# yand and
# sursuits pursuits
# plaace place
# anyd and
# theii their
# devmed deemed
# clevejr clever
# hras has
# lng long
# destrosyed destroyed
# heareily heartily
# conquesth conquest
# yther other
# qworth worth
# cau can
# abtout about
# sprainin spraining
# preslerver preserver
# capled called
# mornng morning
# ersonal personal
# aeceived received
# gaccount account
# thwe the
# afection affection
# domestia domestic
# fazily family
# accidet accident
# requred required
# delicatd delicate
# cyomplexion complexion
# rfgular regular
# ofeaturs features
# sbister sister
# advantaqe advantage
# heigt height
# khmt khat
# beautilul beautiful
# usualy usual
# spkin skin
# complexibn complexion
# unommonly uncommonly
# smil smile
# attrctivqe attractive
# withoout without
# bahk back
# rmembrance remembrance
# puerfect perfect
# ivacity vivacity
# tusic music
# dancisg dancing
# passionagely passionately
# faourite favourite
# egage engage
# ailk silk
# introduned introduced
# hjad had
# rsserve reserve
# thveir their
# dancbng dancing
# jvudgment judgment
# tcis this
# quistion question
# forwa korwa
# ua a
# nhafv hav
# excellencd excellence
# dolizd solid
# yb b
# osr or
# igf if
# differencue difference
# ethe the
# xould could
# tecisions recisions
# hzer her
# cnncluded concluded
# familhiarity familiarity
# estabslished established
# acquqintane acquaintance
# opiion opinion
# ijn in
# imporftance importance
# hyo yo
# thamn than
# suh such
# favouite favourite
# dcqorum decorum
# apen open
# resehved reserved
# decitful deceitful
# hxd had
# ounly only
# minutek minutes
# musbt must
# convkersation conversation
# oaur our
# plesure pleasure
# evidnt evident
# mwish wish
# improvirg improving
# afxter after
# sufch such
# unnecesnary unnecessary
# recvery recovery
# yyoung young
# imwagination imagination
# livedly lively
# enngage engage
# recommnded recommended
# affectiown affection
# beyon beyond
# graduqlly gradually
# enjoyvent enjoyment
# rsad read
# nread read
# whzch which
# faultlhss faultless
# alnd and
# kto to
# ropensity propensity
# stronrly strongly
# peuliarly peculiarly
# sying saying
# cpircumsqances circumstances
# penople people
# wahere where
# esily easily
# dijslayed displayed
# bnow now
# anq and
# seing being
# unjuntifiable unjustifiable
# unhapy unhappy
# eveuy every
# eeiod period
# thougght thought
# bpy by
# wek we
# ancd and
# fqr for
# discoverend discovered
# perceptizble perceptible
# bbe be
# qdrawn drawn
# gartiality partiality
# remved removed
# anpnexed annexed
# assirgned assigned
# xcitd excited
# hwever however
# resemblmance resemblance
# strrkaing striking
# regrd regard
# uwith with
# mive give
# ery very
# azn an
# hgm him
# successfbl successful
# hartily hastily
# reseave reserve
# spiris spirits
# glooiness gloominess
# disappointxments disappointments
# belieuf belief
# nhe the
# esutewmed esteemed
# slghted sighted
# seeeg skeeg
# cerits merits
# rjust just
# abvut about
# delxhted delighted
# njbody nobody
# rmevmbcers members
# exuctly exactly
# iijustice injustice
# witho with
# patns pains
# conversu converse
# hym him
# certaibnly certainly
# hps his
# ifor for
# ovtahers others
# wquld would
# approded approved
# wyman woman
# commmand command
# ndifference difference
# abuase abuse
# wmake make
# prejudiivced prejudiced
# defenzce defence
# oety oaty
# cgreat great
# worl world
# rej red
# oave have
# yapable capable
# mpuch much
# answere answer
# wieh with
# confecmptuously contemptuously
# troublesom troublesome
# WOUD WOULD
# inforaed informed
# orbservations observations
# tgold told
# mohrs mors
# palaheuins palanquins
# tnture tenture
# stretcled stretched
# dislie dislike
# vetry very
# gho who
# hac had
# woho who
# lhas has
# spgend spend
# feeings feelings
# voic voice
# gvu gu
# hil his
# comparjtively comparatively
# onky only
# agddregs address
# unkivndly unkindly
# dsarm disarm
# convice convince
# stuxborn stubborn
# threatend threatened
# hangiug hanging
# avny any
# respcfts respects
# rreproachable reproachable
# idmapined imagined
# temselves themselves
# shoud should
# sucmh such
# frmequent frequent
# visitorrs visitors
# libttle little
# semployment employment
# woas was
# baeen been
# formig forming
# thce the
# parfties parties
# thq the
# incufed incused
# exacty exactly
# tfe the
# higm him
# opportuniy opportunity
# ekcellencies excellencies
# receving receiving
# ehaviour behaviour
# pointid pointed
# venause because
# zll all
# conceoalment concealment
# tmisgrace disgrace
# sentimejts sentiments
# whih which
# themseqves themselves
# iljaudable illaudable
# usnnecessary unnecessary
# effotq effort
# dishgraceful disgraceful
# scbjectioa subjection
# miastakn mistaken
# iilustration illustration
# diid did
# hk he
# eveynings evenings
# wcere were
# hibmgself himself
# dancin dancing
# fotmed formed
# jhe the
# werie were
# iowduct conduct
# thyem them
# ridiicule ridicule
# seemd seemed
# inclinatio inclination
# devoped devoted
# bw be
# xnot not
# zher her
# pubre pure
# atforded afforded
# supplx supply
# misse miss
# mhad had
# helr her
# hnr her
# mqans means
# partieulars particulars
# wghat what
# vhe the
# minuteh minutes
# mqther mother
# onkly only
# obserovation observation
# calmnesps calmness
# usband husband
# intuimacy intimacy
# stherefore therefore
# ninvariable invariable
# evew ever
# wenre were
# alwas always
# thojugh though
# eldet eldest
# attmnded attended
# nevr never
# appearek appeared
# enjovyment enjoyment
# rpresence presence
# copversation conversation
# sometimks sometimes
# acquainance acquaintance
# ajny any
# companin companion
# questio question
# egard regard
# faz far
# txe the
# fror for
# indiference indifference
# sizster sister
# compzssin compassion
# tshe the
# susprct suspect
# alreadk already
# suspicixn suspicion
# sittirg sitting
# tovgther together
# zothers others
# undersand understand
# aqttachments attachments
# blireve believe
# elizeve believe
# lontrives contrives
# roeflecting reflecting
# hur her
# whj who
# hdowever however
# opifons opinions
# obn on
# observanion observation
# justimy justify
# probaoly probably
# replieq replied
# somethin something
# ayiable amiable
# prejuudices prejudices
# youg you
# wly way
# cangot cannot
# incnveniences inconveniences
# enethsiasm enthusiasm
# mgnodrance ignorance
# xor for
# ubfortunate unfortunate
# teandency tendency
# acquaineance acquaintance
# wgat what
# ausv aus
# sisoter sister
# pno no
# hve he
# cxheir cheir
# tthe the
# bject object
# equaly equally
# indifferlnt indifferent
# duning during
# nly only
# inltance instance
# sgcond second
# attaychmnt attachment
# paronable pardonable
# succeedcd succeeded
# exprience experience
# onc on
# fgreatly greatly
# resebled resembled
# rsister sister
# inforcged informed
# bof of
# unfowrtunate unfortunate
# otferwise otherwise
# entesred entered
# woulad would
# sudspicion suspicion
# covinced convinced
# concernd concern
# zslight slight
# onnect annect
# wousd would
# formewd formed
# unser under
# hyr her
# ltive live
# ths the
# moszt most
# yof of
# disasrous disastrous
# wzalking walking
# togethenr together
# latte late
# pioece piece
# spie spite
# thfat that
# urprised surprised
# extravagagnt extravagant
# calmculated calculated
# conkidering considering
# thay that
# bthis this
# tbuild build
# iwithout without
# hesivtation hesitation
# ryptures raptures
# incends intends
# intg into
# arripes arrives
# eevery every
# gabllop gallop
# shome some
# thqese these
# unwrilling unwilling
# suc such
# toich touch
# thf the
# wbould would
# meregst merest
# wdoubt doubt
# popriet propriety
# wfs was
# oj of
# knowin known
# creatulre creature
# opyortunity opportunity
# thmt that
# letermidne determine
# inlufficient insufficient
# acquanted acquainted
# dshzuld should
# greaer greater
# kow now
# mre mrs
# aippeal appeal
# inulgent indulgent
# herrself herself
# tdhyis this
# estabtlishment establishment
# shortlv shortly
# subduec subdue
# promisedd promised
# suwh such
# offeor offer
# exprhsss express
# lon on
# presejnt present
# isame same
# furejr lurer
# entrpeaty entreaty
# iowever however
# zearnestness earnestness
# noow now
# shagll shall
# ome me
# bzceive receive
# yqou you
# thde the
# addressisng addressing
# fnqtimacy intimacy
# ldecided decided
# thant that
# mment moment
# enxgaged engaged
# anw and
# oyher other
# shouald should
# mattr matter
# precediong preceding
# aond and
# nsome some
# aned and
# vwntr owner
# impoctant important
# communicatoed communicated
# sistsr sister
# cied cried
# htve have
# firast first
# believ believe
# cetain certain
# pictvre picture
# grjat great
# seemex seemed
# presestly presently
# har her
# tumtbled tumbled
# foldey folded
# particulzars particulars
# coquld could
# nost not
# wiqthhold withhold
# trhe the
# padrticular particular
# xa a
# madtter matter
# grvat great
# curiosiy curiosity
# couse house
# ueffort effort
# convnced convinced
# nhavt that
# perso person
# bbear bear
# composurze composure
# jok joy
# wxth with
# mrost most
# ved bed
# gngry angry
# conjekctures conjectures
# rjepeat repeat
# rplied replied
# sait said
# entleman gentleman
# veyriy very
# ohis his
# scurate curate
# pofession profession
# inventon invention
# peson person
# latjly lately
# obsering observing
# beliedved believed
# prooeed proceed
# friom from
# thao that
# vfrom from
# sukjects subjects
# raillory raillery
# starped started
# wmo who
# mindfpl mindful
# feeliogs feelings
# botnh both
# oepened opened
# askemd asked
# variout various
# endeavours endeavour
# qxit quit
# recgover recover
# plarm alarm
# intf into
# fordmed formed
# followig following
# lw law
# witiout without
# iterest interest
# eek week
# hapd had
# dxclared declared
# beauqiful beautiful
# particulzarly particularly
# tfheir their
# vssit visit
# amusemint amusement
# sbtyle style
# unertaing uncertain
# alofady already
# cld old
# hwome home
# ipntended intended
# turnid turned
# nfrom from
# prvepared prepared
# wdt wit
# fatigsed fatigued
# ayt at
# wele were
# breakfazt breakfast
# aqs as
# disperlsing dispersing
# frquequly frequently
# hicgh high
# oood good
# inzconveniences inconveniences
# tehan than
# lxetters letters
# directisn direction
# immediatlle immediately
# tnhe the
# mavtei matter
# auddenly suddenly
# fivve five
# minuts minutes
# retxurned returned
# enrered entered
# hlpe hope
# merey merely
# pso so
# ombe combe
# zcome come
# trth truth
# withoput without
# daughte daughter
# repoof reproof
# inded indeed
# kyow know
# colourincg colouring
# addessing addressing
# togay today
# busness business
# immedvate immediate
# oabliged obliged
# lenave leave
# cncerned concerned
# presece presence
# admitance admittance
# hotekeeper hotelkeeper
# alq all
# chould could
# yiou you
# retnurn return
# carnnot cannot
# pwho who
# tcannot cannot
# afrid afraid
# reqlied replied
# cange change
# ojd old
# thintk think
# gbetter better
# qthe the
# gomt got
# sokrow sorrow
# disappqointing disappointing
# eclared declared
# ccome come
# qust must
# oblioing obliging
# unjcertyain uncertain
# rezurn return
# aat at
# aljl all
# nhere there
# ehaps whaps
# ouw out
# busines business
# bdo do
# ghen when
# oyou you
# brttr better
# ook look
# ojf of
# sisteys sisters
# nsne none
# myust must
# bkowed bowed
# ggoing going
# asout about
# lamwntations lamentations
# whyich which
# disappwoonted disappointed
# guesfs guess
# bbusness business
# showever however
# boxdy body
# cmust must
# relaution relation
# hcs his
# rhim him
# starce scarce
# heartvily heartily
# grneraf general
# rexgret regret
# conclcding concluding
# howevem however
# obsercving observing
# bejng being
# afeter after
# consultatiov consultation
# aghreed agreed
# pthat that
# althaugh although
# ejoyed enjoyed
# tey they
# clmposure composure
# orderey ordered
# whcn when
# zery very
# wps was
# redturn return
# delighqed delighted
# thecr their
# tems tem
# shbuld should
# exremely extremely
# vday day
# oqsxrved observed
# wvth with
# yefore before
# swid said
# qou you
# ppite spite
# kinow know
# spgent spent
# smornin morning
# reslied replied
# rnot not
# nto to
# ouct out
# yearps years
# awy any
# gteat great
# confusio confusion
# resolutiown resolution
# wrere were
# methom method
# considercble considerable
# walkin walking
# tto to
# sghould should
# tyo to
# gaeat great
# surprisu surprise
# ound found
# impovssible impossible
# moyrning morning
# ikn in
# pleasartness pleasantness
# propiiet propriety
# cpntrary contrary
# bbeen been
# anby any
# shogld should
# akd and
# pleasur pleasure
# ymou you
# imertinent impertinent
# hproof proof
# improkpriety impropriety
# varue value
# commeddation commendation
# alking talking
# weree were
# yuou you
# visibl visibly
# grtifyig gratifying
# ater after
# intervial interval
# hplace place
# spze size
# woulbd would
# derlightful delightful
# sids side
# ybou you
# acryss across
# gren grey
# behigd behind
# othing thing
# bukt but
# fittted fitted
# cuple couple
# pheasantest pleasantest
# oom room
# housg house
# conicealing concealing
# evey every
# taks take
# coxmngs comings
# sre she
# kinm kind
# befalyen befallen
# shoqld should
# mzlanchly melancholy
# afzaid afraid
# reckonfed reckoned
# tawo two
# everythig everything
# fwadly gladly
# mattrs matters
# gof of
# idt it
# becaluse because
# shd she
# qill will
# worfd world
# ikely likely
# abou about
# xbe be
# estaxe estate
# xtie tie
# sistqer sister
# souch such
# tdrouble trouble
# bargaie bargain
# oinion opinion
# vqryin varying
# freeh free
# requally equally
# reall really
# onder under
# suddeunlm suddenly
# ewws ewes
# hezr her
# besdeks besides
# ehac chac
# variey variety
# discosed disposed
# silnce since
# cof of
# sthey they
# invompatible incompatible
# hersef herself
# behnaviour behaviour
# declaried declared
# jhave have
# tken then
# cimaginp imagine
# easly easily
# migt might
# bhe the
# immedistely immediately
# tlhough though
# rveason reason
# ohn on
# abour about
# shven seven
# yetr yet
# hften often
# engagesent engagement
# waus was
# contbfdictozy contradictory
# dpinions opinions
# revally really
# preveqt prevent
# thaan than
# givg give
# ajd and
# waks was
# anrd and
# andd and
# lved lived
# spegt spent
# engageent engagement
# tqe the
# texercise exercise
# caxlled called
# mornnrg morning
# csertain certain
# fhis his
# favouqite favourite
# particulau particular
# hik his
# oten often
# bjects objects
# desipgn design
# affecrion affection
# perfqect perfect
# cthis this
# nevir never
# tvo to
# scrifice sacrifice
# locadl local
# anfy any
# wdom whom
# unemploced unemployed
# crather rather
# pbifful painful
# jn in
# fauzltless faultless
# wbuilding building
# thoe the
# exac exact
# ritohn kriton
# bager eager
# varciation variation
# onlv only
# mysyelf myself
# elven even
# boader bolder
# emdegar bedegar
# qplacbe place
# otheu other
# loked looked
# dded added
# coqtage cottage
# lnever never
# siuation situation
# ggrieving grieving
# twen then
# qhould should
# cfrom from
# inuto into
# anzd and
# uothing nothing
# prescince prescience
# happvness happiness
# accoun account
# voipe voice
# houus hours
# wnich which
# oithin within
# accommodayion accommodation
# possiblsy possibly
# attempteqd attempted
# iarmly warmly
# promisw promise
# oly only
# wdill will
# wthat that
# unchaznged unchanged
# djwelling dwelling
# givn give
# degclared declared
# affecton affection
# witth with
# pthe the
# opf of
# exczsed excused
# nmother mother
# callding calling
# abgsent absent
# perfetl perfectly
# eith with
# qremaining remaining
# rnturn return
# parz park
# uound found
# cnvinced convinced
# conjwcture conjecture
# yust must
# ftaught taught
# shoner sooner
# hn in
# apparevntly apparently
# iolent violent
# aflfliction affliction
# handkerhief handkerchief
# sxtairs stairs
# ytowafrds towards
# strngly strongly
# eootion emotion
# mattier matter
# crked cried
# nodt not
# ceerful cheerful
# bc be
# sufferirng suffering
# ander under
# thtis this
# exercisd exercise
# privilefe privilege
# rches riches
# sendinn sending
# buiness business
# receved received
# ydispatches dispatches
# ajnd and
# exhilration exhilaration
# fkarewell farewell
# thifs this
# unfrtuonate unfortunate
# immbdiately immediately
# twelvemont twelvemonth
# yojur your
# anp and
# uon on
# nround round
# okcly only
# bgood good
# silet silent
# tthat that
# retsrn return
# gjudge judge
# ioubt doubt
# inclinvation inclination
# prsent present
# pmyself myself
# suceqded succeeded
# impossibcle impossible
# noiw now
# enuoy enjoy
# lezt left
# cjarriage carriage
# sigvt sight
# fevlt felt
# owcasioned occasioned
# behaviojr behaviour
# hiws his
# embarassment embarrassment
# acceet accept
# invitatioz invitation
# disturbec disturbed
# unfwortunate unfortunate
# aken taken
# ehim him
# diserexs distress
# quiitted quitted
# ruasonably reasonably
# considerced considered
# seemwd seemed
# sistew sister
# indubitble indubitable
# nompgassion compassion
# proability probability
# rl al
# unchrful uncheerful
# deaar dear
# sgid said
# hapy happy
# csheerful cheerful
# qten ten
# minutis minutes
# notoice notice
# lfe life
# unwillngness unwillingness
# yogur your
# invitaaion invitation
# qwanted wanted
# pwer power
# hbave have
# explaineo explained
# dou you
# OU OF
# suspectrs suspects
# ecause because
# ginvented invented
# bexcuse excuse
# betieve believe
# dipsapprove disapprove
# onnection connection
# hifs his
# deplendent dependent
# situaton situation
# anwd and
# pild wild
# happvenwgd happened
# liten listen
# poitt point
# understaxnding understanding
# ansser answer
# tnold told
# incomprdhensipble incomprehensible
# upnon upon
# crediut credit
# midsery misery
# reiolved resolved
# toaok took
# ois his
# spiirits spirits
# depresse depresses
# recen recent
# becuse because
# wve we
# thpe the
# possibiclity possibility
# unansweerable unanswerable
# themselve themselves
# mqsexf myself
# suspicicn suspicion
# unpleosant unpleasant
# alteratin alteration
# ijust just
# whaf what
# havve have
# cndid candid
# bevery every
# sudfficient sufficient
# lreasons reasons
# acrnowledge acknowledge
# practced practiced
# necesszry necessary
# aijd aid
# thiws this
# concegaling concealing
# yies yes
# reproachminig reproaching
# ssid said
# engagezent engagement
# perfecly perfectly
# sylladbles syllables
# actionhs actions
# nnd and
# uzs us
# dast last
# fortnngeht fortnight
# consikered considered
# thn the
# anteachen unteaches
# kf of
# ealch each
# pissible possible
# musp must
# ynkd and
# monhs months
# sholy holy
# withot without
# exchaenge exchange
# replie replied
# thjat that
# dngagement engagement
# noth not
# oter other
# strane strange
# rou you
# smster sister
# trhis this
# xure sure
# tendernes tenderness
# casn can
# leiave leave
# indifgference indifference
# axs as
# thabt that
# cobnfess confess
# ainter winter
# aqnd and
# emoved removed
# mighxy mighty
# comcessiog concession
# nno no
# sufh such
# atteopted attempted
# uniformlr uniformly
# dopen open
# tderefore therefore
# maon man
# honousr honour
# suspikion suspicion
# hnas has
# inoluntary involuntary
# enourage encourage
# starled started
# sikuation situation
# leuave leave
# ruturning returning
# eclining declining
# acbt act
# ungemnerous ungenerous
# distrbed disturbed
# difficltxes difficulties
# sthin thin
# geeral general
# consistnt consistent
# suspeced suspected
# liong long
# iondependently independently
# marjy marry
# bjen been
# hhat that
# interruptd interrupted
# entrancte entrance
# othe the
# reperesentaions representations
# packnowledge acknowledge
# probazbility probability
# notrhing nothing
# wsithout without
# swolen stolen
# iher her
# qwete were
# diffixulty difficulty
# fter after
# presing pressing
# tendrer tender
# comppssion compassion
# fotpitude fortitude
# quitle quite
# eppressiokn expression
# withofut without
# msntion mention
# relatcive relative
# ovepowered overpowered
# ost out
# attetive attentive
# imposspble impossible
# feeliqngs feelings
# gwth goth
# herlelf herself
# mble able
# irst first
# wyould would
# olook look
# inext next
# nked need
# cuch such
# compolsre composure
# pamrt part
# fith with
# unwiwling unwilling
# alcl all
# sensibilidy sensibility
# mby by
# hersehlf herself
# wanderey wandered
# nindulging indulging
# recollectin recollection
# jenjoyment enjoyment
# cryng crying
# orver over
# reerse reverse
# ypassed passed
# ceeling feeling
# flvourite favourite
# everb every
# whiech which
# thegr their
# ftenest oftenest
# oritten written
# hkr her
# pignoforte pianoforte
# toylxly tolly
# vevr ver
# ytears years
# musmic music
# corted courted
# etween between
# cerhain certain
# rsead read
# bje be
# toether together
# afflicion affliction
# ejployments employments
# returred returned
# producjed produced
# occasionlal occasional
# xpecbted expected
# suprised surprised
# exzlanations explanations
# whenrever whenever
# stisfied satisfied
# etters letters
# mustt must
# orrespondence correspondence
# mhtive motive
# simplh simple
# opninion opinion
# regoving removing
# nhether whether
# engagef engaged
# motr mor
# qulstion question
# offbnce offence
# rsult result
# unnresrerve unreserve
# nsucmh such
# gould could
# fbe be
# phoulld should
# confessiorn confession
# unacknolldged unacknowledged
# deatrly deathly
# thbe the
# circumstatces circumstances
# confdence confidence
# dikrect direct
# thouhght thought
# genperosity generosity
# overstraned overstrained
# comnsimdering considering
# yher her
# alxl all
# sevewral several
# ennings kennings
# ineed indeed
# noi not
# evyning evening
# exclaied exclaimed
# adgain again
# perhlaps perhaps
# wsioh with
# stronr strong
# smurprise surprise
# wbas was
# whnat what
# knwlwedge knowledge
# inttead instead
# wfayndering wandering
# atay away
# hervself herself
# toards towards
# climxing climbing
# wden when
# skecured secured
# bwho who
# greatml great
# dirapproved disapproved
# couli could
# fcontrolled controlled
# onm on
# ctuntry country
# ricrh rich
# streth stret
# trwvelltd travelled
# combng coming
# reachig reaching
# formejd formed
# distnce distance
# tlhxey they
# nevelr never
# hppened happened
# horsebtack horseback
# ayfterwards afterwards
# hastning hastening
# mejt meet
# cqied cried
# surs sure
# oknew knew
# ihe the
# lmost most
# quicokerned quickened
# yvrdt yards
# agai again
# uturning turning
# hsrrying hurrying
# rainsed raised
# wslurprise surprise
# seye see
# coulf could
# momenjt moment
# frogm from
# teo to
# disappoinotment disappointment
# dismounzd dismounted
# hxrse horse
# servaut servant
# whitqher whither
# tqo to
# grmeat great
# tnat that
# coldess coldness
# xwhich which
# oftezn often
# pamticulaly particularly
# adeficiency deficiency
# ouhb out
# blook look
# sutch such
# littlb little
# fsorced forced
# hzim him
# distinguibed distinguished
# incresking increasing
# almosn almost
# ffeel feel
# evern every
# carryijg carrying
# lwhose whose
# conxtrast contrast
# suffidiently sufficiently
# tehose those
# ofirst first
# meetinwg meeting
# jsked asked
# fortynight fortnight
# samy say
# dexr dear
# dwear dear
# walyks walks
# tcickly trickly
# showes showed
# felings feelings
# seayon season
# teqe tete
# thwem them
# swext sweet
# driiven driven
# undertood understood
# prxospect prospect
# toanquil tranquil
# cac can
# lgeft left
# thosf those
# beeath breath
# thyt that
# cottcge cottage
# beautifu beautiful
# wintes winter
# dzirt dirt
# wnith with
# objcts objects
# orewlfied replied
# befor before
# lne one
# herselb herself
# waxlked walked
# lcried cried
# sester sister
# friendliehst friendliest
# uoments moments
# kheir their
# yoccasional occasional
# rathepr rather
# presnent present
# apdpearance appearance
# ctreated treated
# connction connection
# opinio opinion
# rthe the
# naturael natural
# aoy any
# expretsion expression
# coldnes coldness
# stagnd stand
# enteed entered
# lquite quite
# eithet either
# somn some
# howeqer however
# prospet prospect
# attentivee attentive
# fxamily family
# perjceived perceived
# attriduting attributing
# mothgr mother
# tabls table
# prsbnt present
# oratsor orator
# convincned convinced
# ror for
# pblic public
# muvst must
# youmr your
# istrangers strangers
# profossion profession
# atsurance assurance
# vshall shall
# ttempt attempt
# distingsuishted distinguished
# cannoj cannot
# wecl well
# blieve believe
# pwel peel
# dh do
# lgittle little
# shappiness happiness
# ele else
# ral real
# ssy say
# jithout without
# thvm them
# thoussand thousand
# moderatde moderate
# extravagat extravagate
# pfoper proper
# enstablishmeq established
# servarts servants
# perhapxs perhaps
# swo so
# sistezr sister
# dscribing describing
# ymost most
# strliking striking
# thougut thought
# lage large
# fortue fortune
# animatio animation
# cheegs cheeks
# unaimous unanimous
# spity spite
# minsufficiency insufficiency
# hnappy happy
# witph with
# shourld should
# puzzlen puzzled
# wepre were
# syon soon
# vaish taish
# travael travail
# famly family
# mosic music
# comminsion commission
# thre the
# ntent intent
# kcopy copy
# hads had
# wiklling willing
# lohe love
# crecall recall
# hleast least
# improsving improving
# yulk hulk
# theik their
# wwzth with
# rewanrd reward
# cin in
# pointt point
# ime me
# tolxrably tolerably
# likeqly likely
# nw no
# chtange change
# stewadfast steadfast
# altdred altered
# tnly only
# grogn grown
# ygay gay
# pcrt part
# skaid said
# girj girl
# rreally really
# habve have
# alwavs always
# nhave have
# uch such
# misfpprehension misapprehension
# uf of
# charactr character
# fazncying fancying
# grlve grave
# imngenious ingenious
# ibs is
# withoubt without
# righp right
# rhas has
# dctrine doctrine
# nevq neve
# underttanding understanding
# attempe attempt
# nfluence influence
# muxst must
# oftben often
# hreat great
# gyeater greater
# servous serious
# loroking looking
# jyour your
# eever ever
# osffend offend
# oftkn often
# comhany company
# lffect effect
# ctuld could
# perfegctly perfectly
# gracefu graceful
# bne be
# heserved deserved
# qlooked looked
# undberstan understand
# fasst fast
# rapdurously rapturously
# aniswer answer
# gravitpy gravity
# thouthtulness thoughtfulness
# returef returf
# aforded afforded
# sxatisfacytion satisfaction
# hicf hic
# praferenoe preference
# contradicte contradicted
# wjo who
# asways always
# havppiness happiness
# sshe she
# coupqd couped
# cbefore before
# wmy my
# uhstairs upstairs
# nheaod heard
# turhipng turning
# khe the
# retulrned returned
# aydmiration admiration
# tge the
# hdd had
# kparts parts
# thh the
# advantdge advantage
# situvation situation
# wholfe whole
# exceedingey exceedingly
# beginqning beginning
# mipnutely minutely
# particulasly particularly
# kwhen when
# nterrunteed interrupted
# noat not
# enqumire enquire
# havw have
# oyfend offend
# ignmorance ignorance
# hilxls hills
# wjhich which
# whirh which
# irreguljar irregular
# bwhich which
# indistinlct indistinct
# admiratikon admiration
# hilli hills
# aare are
# tbe the
# meadoww meadowy
# huuses houses
# hxre here
# tere were
# exactl exactly
# countr country
# pituresque picturesque
# promontoriges promontories
# brysh brash
# pircturesque picturesque
# shid said
# anoter another
# fpeel feel
# sucoh such
# awnd and
# himsflf himself
# uhe the
# afectatiotn affectation
# admiratin admiration
# defised defied
# meauty beauty
# arrgon argon
# sometives sometimes
# havt have
# fexlings feelings
# myqself myself
# EI I
# descrgbe describe
# hacneyed hackneyed
# priniples principles
# twioted twisted
# admqre admire
# sthem them
# flourishihg flourishing
# likv like
# fnd and
# tistles istles
# heatmh heath
# fary far
# ztidy tidy
# inet int
# banrditti banditti
# objec object
# hih his
# frngers fingers
# giee give
# muph much
# hmr her
# vexatko vexation
# vejy very
# deepldy deeply
# alwavys always
# ifferent different
# iand and
# mthe the
# differenfce difference
# whxat what
# xrocured procured
# rherself herself
# soething something
# iynternally internally
# henceuforward henceforward
# nll all
# bshade shade
# sose some
# mrning morning
# severly severely
# offece offence
# iddle idle
# wko who
# artrival arrival
# surve sure
# assistanoce assistance
# ldw law
# kuture future
# ryailgery raillery
# acquaintane acquaintance
# pould could
# prebted pressed
# immediategly immediately
# sigjificant significant
# bhow how
# penetfration penetration
# withoiut without
# edrink drink
# preent present
# bettekr better
# theia their
# viitor visitor
# engagme engage
# rfor for
# VOU YOU
# mhought thought
# nobuody nobody
# peuon pelon
# tvat that
# shalb shall
# bjushing blushing
# suspiclons suspicions
# dward edward
# voicie voice
# hkm him
# countenne countenance
# cemprehend comprehend
# expressios expression
# ismediately immediately
# routd round
# hhave have
# xyou you
# yofu you
# tzhat that
# wgs was
# confuused confused
# smilineg smiling
# quie quite
# rchness richness
# moent moment
# douyt doubt
# astonshed astonished
# ilagined imagined
# betwmeen between
# resolvec resolved
# godne gone
# wenn went
# friendb friends
# ghevight height
# uaequal unequal
# greastly greatly
# lvirous virous
# hij his
# whozlly wholly
# vace face
# siould should
# hukkly hugely
# musw must
# eeek week
# eastonishing astonishing
# oyf of
# zacfing acting
# excucs excuss
# osf of
# disrleased displeased
# dispsed disposed
# actios action
# ...
# wokuld would
# eecomi become
# propriedy propriety
# improprietoy impropriety
# speqedily speedily
# withou without
# feelvng feeling
# refcection reflection
# resolutioe resolution
# recitak recital
# addrss address
# reljated related
# honewtly honestly
# protstations protestations
# reard heard
# trembmed trembled
# becaee became
# sicknes sickness
# lesft left
# dayed dared
# syllablie syllable
# stster sister
# tira tiza
# towqrds towards
# thzey they
# cottase cottage
# conjecturisng conjecturing
# tvough though
# conversatfon conversation
# carfully carefully
# loeok look
# minuteress minuteness
# gratixud gratitude
# wods words
# sisber sister
# attemit attempt
# uolitude solitude
# reuolution resolution
# dhould should
# gindiction indiction
# yorry sorry
# hbm him
# nbroken broken
# fthrough through
# coulpd could
# daugahter daughter
# eeard heard
# itnessed witnessed
# besn been
# wosld would
# poer poor
# calmnjess calmness
# cwn own
# wisehed wished
# tedenesc tenderness
# evenint evening
# thrue three
# withouq without
# sbeen been
# unteady unready
# votce voice
# plaknly plainly
# assuare assure
# realjly really
# mz my
# morninxg morning
# imoments moments
# rqecoverint recovering
# perofuctly perfectly
# knowp know
# qonfidenece confidence
# motyher mother
# frmends friends
# hearjt heart
# cocnscience conscience
# qonscience conscience
# hubnband husband
# consirder consider
# undrerstanding understanding
# reasoj reason
# upported supported
# affeclion affection
# mbch much
# certavin certain
# hyou you
# mumst must
# whave have
# expensivenss expensiveness
# acknolwledged acknowledged
# cognduct conduct
# undesteood understood
# hmvie have
# grzievous grievous
# hving having
# untught untaught
# perwaps perhaps
# retrenced retrenched
# yowur your
# migbht might
# huw how
# littl little
# hhwever however
# prevaoiling prevailing
# regrt regret
# connectioln connection
# rteazly really
# fron from
# begining beginning
# affai affair
# groundead grounded
# pirst first
# finaly finally
# carlied carried
# enjoymnt enjoyment
# presunt present
# continud continued
# donhe done
# begret regret
# fdds fids
# twards towards
# nobt not
# hapqy happy
# qcircumstances circumstances
# sufferb suffer
# womao woman
# leses less
# tjmper temper
# folow follow
# inconvenieces inconveniences
# thhen then
# ruffered suffered
# pecniary pecuniary
# makqe make
# lways always
# probaby probably
# jlearnaed learned
# xto to
# faw saw
# hppiness happiness
# wifj wife
# aeianne marianne
# lothing nothing
# ffolly folly
# yoor your
# woucd would
# avoimd avoid
# othat that
# spiripts spirits
# isubject subject
# immkdiately immediately
# mry my
# awhole whole
# dfficultties difficulties
# fqrst first
# xadainst against
# beben been
# une one
# enueration enumeration
# mepits merits
# cjuld could
# dictae dictate
# howevmer however
# hemrd heard
# mthree three
# resolutioyn resolution
# appeqr appear
# eturned returned
# altl all
# settped settled
# anod and
# stuies sties
# viour vigour
# fizrse first
# levast least
# imptatient impatient
# dsome some
# haxd had
# nothidg nothing
# crtain certain
# lwetters letters
# burotaer brother
# conseuence consequence
# nothoing nothing
# dno no
# prohipbited prohibited
# cnclude conclude
# qstill still
# whgich which
# intelligenje intelligence
# dwrd dird
# affordjd afforded
# mebntioned mentioned
# lettders letters
# lons long
# ignrance ignorance
# meeasures measures
# moning morning
# ywhen when
# inquijies inquiries
# errqnd errand
# thid this
# communmication communication
# uppose suppose
# startt starty
# dsaw saw
# servnt servant
# tqken taken
# countenanzce countenance
# afterlards afterwards
# situatitn situation
# cfll call
# intjo into
# ogher other
# tqime time
# rqther rather
# betkter better
# retuqned returned
# visordered disordered
# recvxred recovered
# zoice voice
# trrouble trouble
# morninag morning
# hjs his
# stpping stepping
# haise raise
# youngrst youngest
# tgo to
# sevice service
# comy come
# hrrry harry
# furthdr further
# howevexr however
# mayke make
# matrried married
# siles miles
# rahrts parts
# ualways always
# afable amable
# behved behaved
# jzy joy
# lening leaning
# genxleman gentleman
# accouno account
# puttwing putting
# farthfer farther
# mla ma
# lcong long
# wiwll will
# thebn then
# loxked looked
# ricognised recognised
# ohey they
# goig going
# dobwn down
# intelligeice intelligence
# nished wished
# jusbt just
# cominn coming
# araid afraid
# cntented contented
# shovuld should
# herseltf herself
# moeals meals
# ybliged obliged
# themselvec themselves
# simiarity simianity
# kazard nazard
# ufond fond
# represenation representation
# herseflf herself
# softenei softened
# unhappintss unhappiness
# almos almost
# bmifght might
# dnughter daughter
# provocataon provocation
# greatefr greater
# expzctaxion expectation
# lvent event
# eto to
# lconsideo consider
# wgrtainty certainty
# fbound found
# remaikned remained
# somethintg something
# somv some
# arisie arise
# marrierd married
# intlligence intelligence
# porsession possession
# hov how
# shouold should
# rissk risk
# bexing being
# pacqe pace
# xonspired conspired
# witu with
# parsonagee parsonage
# ubiting biting
# smarit smart
# ble be
# uspeceed suspected
# ecoromical economical
# pyractices practices
# favouw favour
# sketh sketch
# ecent event
# farteher farther
# bassed passed
# brooght brought
# inqsuiry inquiry
# furom from
# miknd mind
# somehing something
# mlast last
# ehbim him
# informaton information
# determned determined
# honseback horseback
# ahear hear
# awvare aware
# wthksper whisper
# understankd understand
# appeam appear
# uctterance utterance
# tzheir their
# dipscretion discretion
# footteps footsteps
# hze he
# thp the
# hppy happy
# fogr for
# cconscious conscious
# merityed merited
# howevejr however
# whojm whom
# epvery every
# mwet meet
# comlycency complacency
# movd moved
# syaken shaken
# gcountenance countenance
# retreakted retreated
# understajnding understanding
# xthought thought
# inxumbent incumbent
# maiqntained maintained
# seasy easy
# thal that
# lhurried hurried
# paxse pause
# resoljving resolving
# thoeugh though
# witn with
# bork work
# peralexed perplexed
# looged looked
# brothrer brother
# yrou you
# mqean mean
# ROERT ROBERT
# amazempent amazement
# angd and
# noct not
# ewven even
# impatienh impatient
# sdeat seat
# whab what
# botu both
# cubtting cutting
# lautter latter
# spwke spoke
# hurriud hurried
# syat sat
# oxver over
# dnr dr
# iqto into
# thougft thought
# asny any
# immeditely immediately
# aftierwards afterwards
# cddrexs address
# pfenetrate penetrate
# towrds towards
# leavig leaving
# preatest greatest
# perpexity perplexity
# chango change
# wonderbul wonderful
# lesseninxg lessening
# bonjectures conjectures
# nowever however
# dre are
# detempned determined
# zfor for
# mlessings blessings
# edgagement engagement
# wjthout without
# nothinig nothing
# qustion question
# uvncomfortfbla uncomfortable
# reaaly really
# ncouragement encouragement
# rceived received
# newed need
# tpld told
# xfour four
# clck clock
# agater agates
# anrrivael arrival
# sother mother
# ndeed indeed
# raiye raise
# rproach reproach
# forbed forced
# miwsery misery
# froy from
# cgeased ceased
# elevnated elevated
# securpity security
# anotcer another
# elearnt learnt
# jwith with
# ldesire desire
# dofubt doubt
# genujne genuine
# flonwing flowing
# befjre before
# itj it
# gttachmnt attachment
# teeated treated
# rll all
# ignity dignity
# tzwenty twenty
# fjour four
# nonsequence consequence
# innorance ignorance
# mey my
# professio profession
# aemoved removed
# woulh would
# nime time
# uncovquernble unconquerable
# prefernce preference
# pusuit pursuit
# enggage engage
# distanyce distance
# kixing fixing
# tworjld world
# thfing thing
# choaen chosen
# bping being
# compsletely completely
# aftzrwards afterwards
# wuhich which
# fobr for
# lovk love
# evesy every
# resrpect respect
# comfcrtable comfortable
# comanion companion
# unnatral unnatural
# dfrom from
# apeared appeared
# preetty pretty
# otherefore therefore
# engagemet engagement
# evkeay every
# inewxcusable inexcusable
# happinets happiness
# promsed promised
# satisflactio satisfaction
# steepless sleepless
# releaae release
# delicaqy delicacy
# togethr together
# enjy enjoy
# hapiness happiness
# fnr for
# nanuage language
# frf fr
# justifyiwg justifying
# foollowed followed
# doubm doubt
# formwer former
# engagzement engagement
# prhfiting profiting
# dezclare declare
# tentder tender
# fixpd fixed
# wyactever whatever
# migit might
# gkiven given
# enjoymen enjoyment
# asuffice suffice
# tablking talking
# betwfeen between
# anqy any
# coammunication communication
# mxad mad
# leajt least
# twenjty twenty
# ramong among
# earligest earliest
# ict it
# extraodinary extraordinary
# unaccountpable unaccountable
# drwn down
# obeauty beauty
# hersaelf herself
# accouvnt account
# comprerension comprehension
# delibghtfu delightful
# imagnation imagination
# reasoqn reason
# exlanatin explanation
# arley arle
# affars affairs
# aplied applied
# hws his
# observaion observation
# erhaps perhaps
# qrocuring procuring
# fyvour favour
# desiygns designs
# aterward waterward
# howevur however
# roemainged remained
# kfr fr
# cgoice choice
# ince once
# heaing hearing
# hersilf herself
# letteru letter
# freqnuent frequent
# folowed followed
# aast last
# niwt nit
# halc half
# stupified stupefied
# betwee between
# vuch such
# delcverance deliverance
# hatve have
# usid used
# wnother another
# yiur your
# toxo too
# enairely entirely
# kre are
# alta altar
# shazl shall
# slister sister
# LJUCY LUCY
# FERRARS FERRARA
# havx have
# fyrst first
# opportunty opportunity
# retuuned returned
# withoft without
# comnment comment
# woulm would
# formei former
# bilushed blushed
# ovyr over
# haulf half
# businesh business
# txhis this
# pleter preter
# qmay may
# aftoer after
# plse else
# mertainly certainly
# mohea bohea
# broughx brought
# aypropriate appropriate
# independende independence
# thhrough through
# resentaent resentment
# yocu you
# apower power
# suppase suppose
# dwill will
# xim him
# hmuch much
# whaw what
# commhunication communication
# icntmate intimate
# connextion connection
# fmat fat
# tve the
# whidch which
# politenes politeness
# tafked talked
# tnot not
# hqe he
# preltily prettily
# imagiation imagination
# usbands husbands
# cleaar clear
# ghimself himself
# thoroughldy thoroughly
# scrhple scruple
# believitng believing
# caxpable capable
# modf mode
# imuted imputed
# diposed disposed
# preveinted prevented
# xud bud
# iim him
# geive give
# renounled renounced
# mothyr mother
# nuzhing nothing
# livng living
# crature creature
# fanvcied fancied
# nrot not
# forksee foresee
# contrinuing continuing
# inclirnation inclination
# dactions actions
# scertainly certainly
# rexpectanle respectable
# gauined gained
# consideraion consideration
# amoong among
# advantageouxs advantageous
# flr for
# coursm course
# ebeen been
# natbural natural
# haqshly harshly
# themsflves themselves
# mych much
# tiume time
# behaoviour behaviour
# wqere were
# ycould could
# timple simple
# wvs was
# cosciouness consciousness
# honoir honour
# amirhd admired
# friedship friendship
# beetween between
# ohow how
# arbguments arguments
# econciled reconciled
# expediercjy expediency
# smled smiled
# rewlly really
# opporunity opportunity
# resentmd resented
# presebnt present
# elivered delivered
# goccasion occasion
# neker never
# himvelf himself
# leittle little
# qglebe glebe
# conxition condition
# lany any
# mpch much
# fxrom from
# tttention attention
# qestion question
# thiks this
# rhal real
# certai certain
# neitheur neither
# quyte quite
# fhr for
# resndve reserve
# theiir their
# ependece dependence
# chusing chosing
# lekser lesser
# vhusing rousing
# yays days
# firt first
# compjany company
# cofmer comer
# therefoore therefore
# jearly early
# evgning evening
# beteen between
# brougt brought
# kibndness kindness
# enqcouragement encouragement
# marrihge marriage
# ceiachsed reached
# wehre were
# fres free
# donfe done
# wouwld would
# advancef advanced
# opkinion opinion
# thedy they
# afvanced advanced
# fovr for
# resblanre resemblance
# princbples principles
# disporitkon disposition
# thinkicg thinking
# beecn been
# ecthout without
# attractinn attraction
# mafde made
# thkt that
# mutuaxl mutual
# efect effect
# judgmnt judgment
# transjkor transfer
# ldess less
# taze take
# vzent vent
# cour your
# cbmpassion compassion
# brokden broken
# bua but
# ssat sat
# ysuspeted suspected
# aenythming anything
# grext great
# mkney money
# wext next
# gcive give
# weeeks weeks
# wfth with
# ojt out
# unfortugnate unfortunate
# woxen women
# cosidered considered
# existsgnce existence
# infinitel infinitely
# inducekd induced
# secgrecy secrecy
# wreatxed wreathed
# othrs others
# zjoin join
# fuluilled fulfilled
# sholld should
# metioned mentioned
# vgreat great
# receivied received
# occasidon occasion
# hewever however
# offeending offending
# letzter letter
# submision submission
# amqss amiss
# errars errors
# tyhat that
# erml eral
# chidren children
# paraograph paragraph
# exagtly exactly
# nanner manner
# pfroper proper
# hmonour honour
# nodr nor
# inqerest interest
# forgicen forgiven
# aross arose
# havinig having
# engmagement engagement
# eyez eyes
# nokhing nothing
# nmake make
# mban man
# reshopved resolved
# inszead instead
# personalt personal
# offitces offices
# evyen even
# saide said
# knqwledge knowledge
# thfence thence
# stedy steady
# luctuating fluctuating
# lifse life
# fortnigho fortnight
# reveaed revealed
# engagemegt engagement
# circkumstance circumstance
# turin turn
# cjonstitutiin constitution
# theprefore therefore
# endeaoured endeavoured
# poweu power
# womjan woman
# higcer higher
# thjt that
# noblman nobleman
# geeleman gentleman
# whwen when
# thopugh though
# repxresentation representation
# plast last
# sujbmit submit
# dfignity dignity
# towapds towards
# augmnting augmenting
# cbonsidered considered
# pplainly plainly
# eljest eldest
# tsoulsand thousand
# pounks pounds
# agbainst against
# takibng taking
# hulndre hundred
# efifty fifty
# mutmost utmost
# hhowever however
# stecmed steamed
# surnprisd surprise
# shus thus
# posession possession
# eamer eager
# considverable considerable
# afttr after
# expcriencing experiencing
# sual usual
# disappintments disappointments
# unaccounbable unaccountable
# eversy every
# shei she
# thiy they
# superinted superintend
# tfing thing
# toyuld tould
# dnard dard
# sohe she
# iheir their
# eall all
# cme me
# authorisen authorised
# honouv honour
# umorning morning
# biefore before
# aying saying
# certainl certainly
# yxung young
# confes confess
# woumd would
# grseat great
# perohaps perhaps
# hdm him
# syeems seems
# poplo polo
# bqe be
# tneated treated
# erned erred
# princhipal principal
# respertful respectful
# attentons attentions
# lattervies flatteries
# estblifhed established
# therefoe therefore
# htld hold
# unceasina unceasing
# aplparently apparently
# ilxl ill
# securinzg securing
# egvery every
# visitied visited
# engagemeut engagement
# affectiob affection
# thtat that
# visjt visit
# antod anton
# produe produce
# whlen when
# avother another
# haelf half
# securd secure
# talkng talking
# thsey they
# alwayzs always
# betayed betrayed
# becav behav
# entmrely entirely
# btrother brother
# hapainess happiness
# rlelations relations
# magnifiuent magnificent
# returninp returning
# instigaition instigation
# adcopted adopted
# forgivenress forgiveness
# comprjhendhed comprehended
# therfefore therefore
# poerseverance perseverance
# condemation condemnation
# gatitude gratitude
# unkindnvlss unkindness
# overcam overcame
# swon soon
# rapd rap
# onmce once
# thougjh though
# supyerior superior
# sbpoken spoken
# ntruder intruder
# kbe be
# favorurite favourite
# libeal liberal
# ashwoods basswoods
# wipl will
# subsistsing subsisting
# dzsagreements disagreements
# alil all
# pyople people
# csucceed succeed
# puzzld puzzled
# wxas was
# justifiemd justified
# ihts its
# efkfects effects
# licving living
# etent event
# brothzer brother
# briznbing bringing
# judgyd judged
# frofm from
# dischare discharge
# cheerfulnss cheerfulness
# spvrits spirits
# uppoed upped
# lmot lot
# divideg divide
# famaily family
# tselss tells
# hadf had
# timqe time
# witqh with
# mogtives motives
# rathoer rather
# oher her
# enjoyent enjoyment
# valaued valued
# mansyibn mansion
# sorfows sorrows
# ietfimate intimate
# wiqh with
# ong on
# everybod everybody
# ftate state
# latne late
# lekss less
# fotmer former
# considewred considered
# souht sought
# pasxion passion
# fondy fond
# rexpectiqng expecting
# pleaures pleasures
# betirement retirement
# nineteyen nineteen
# submittiwng submitting
# plgaced placed
# belived believed
# afjliction affliction
# societny society
# emind mind
# happineass happiness
# dlight delight
# evch each
# colubd could
# mrriage marriage
# puntshment punishment
# complxte complete
# frgiveness forgiveness
# hims his
# souyrce source
# wqith with
# onbce once
# happgy happy
# rch rich
# misconduc misconduct
# punishmenv punishment
# plong long
# whith with
# nnv nov
# thdt that
# habital habitat
# iust must
# dependd depended
# nezither neither
# ekert exert
# frgquently frequently
# himsele himself
# ntt not
# uncomforaboe uncomfortable
# evpry every
# inconsiderarle inconsiderable
# dmestic domestic
# hoiwever however
# incivilitx incivility
# decideod decided
# intyerested interested
# staandarpd standard
# perfectixi perfection
# wlighted alighted
# resached reached
# higtly highly
# suitble suitable
# loven love
# qeasqt least
# consideraple considerable
# almot almost
# geach each
# otheq other
# bingreement agreement
# peroducing producing
